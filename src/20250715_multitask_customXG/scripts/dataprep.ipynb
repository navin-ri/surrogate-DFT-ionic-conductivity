# %%
# import
import pandas as pd

matminer = pd.read_csv('/Users/navin/Library/CloudStorage/Dropbox-AIZOTH/研究/Navin/NIMS/surrogate-DFT-ionic-conductivity/src/20250715_multitask_customXG/data/basic_matminer.csv')
simple = pd.read_csv('/Users/navin/Library/CloudStorage/Dropbox-AIZOTH/研究/Navin/NIMS/surrogate-DFT-ionic-conductivity/src/20250715_multitask_customXG/data/structural_features.csv')

bvel13k = pd.read_csv('/Users/navin/Library/CloudStorage/Dropbox-AIZOTH/研究/Navin/NIMS/surrogate-DFT-ionic-conductivity/src/20250715_multitask_customXG/data/BVEL13k_index.csv')
bvse122k = pd.read_csv('/Users/navin/Library/CloudStorage/Dropbox-AIZOTH/研究/Navin/NIMS/surrogate-DFT-ionic-conductivity/src/20250715_multitask_customXG/data/nebBVSE122k_index.csv')

# %%
# Aggregate the NEB Li+ migration energy (Only nebBVSE122K)
aggregated_122k = (
    bvse122k.groupby('material_id').agg(
        em_min=('em', 'min'),
        em_mean=('em', 'mean'),
        em_std = ('em', 'std'),
        n_paths = ('em', 'count')
        ).reset_index()
    )

# %%
# Merge the prediction of the material
merged_matminer = pd.merge(matminer, simple, on='material_id', how = 'inner')
merged_p_df = pd.merge(merged_matminer, bvel13k, on='material_id', how = 'left')
merged_df = pd.merge(merged_p_df, aggregated_122k, on='material_id', how = 'left')

# %% [markdown]
# ### Used Data wrangler to manually clean the columns to keep only few select structural features

# %%
"""
Cell generated by Data Wrangler.
"""
def clean_data(merged_df):
    # Drop column: 'energy_above_hull_x'
    merged_df = merged_df.drop(columns=['energy_above_hull_x'])
    # Drop column: 'Unnamed: 0'
    merged_df = merged_df.drop(columns=['Unnamed: 0'])
    # Drop columns: 'compound possible', 'max ionic char' and 3600 other columns
    merged_df = merged_df.drop(columns=['compound possible', 'max ionic char', 'avg ionic char', 'Ac - Ac bond frac.', 'Ac - Ag bond frac.', 'Ac - Al bond frac.', 'Ac - Au bond frac.', 'Ac - B bond frac.', 'Ac - Ba bond frac.', 'Ac - Bi bond frac.', 'Ac - Br bond frac.', 'Ac - Ca bond frac.', 'Ac - Cd bond frac.', 'Ac - Ce bond frac.', 'Ac - Cl bond frac.', 'Ac - Cr bond frac.', 'Ac - Cs bond frac.', 'Ac - Cu bond frac.', 'Ac - Dy bond frac.', 'Ac - Er bond frac.', 'Ac - Eu bond frac.', 'Ac - F bond frac.', 'Ac - Fe bond frac.', 'Ac - Ga bond frac.', 'Ac - Ge bond frac.', 'Ac - H bond frac.', 'Ac - Hg bond frac.', 'Ac - Ho bond frac.', 'Ac - I bond frac.', 'Ac - In bond frac.', 'Ac - Ir bond frac.', 'Ac - K bond frac.', 'Ac - La bond frac.', 'Ac - Li bond frac.', 'Ac - Lu bond frac.', 'Ac - Mg bond frac.', 'Ac - Mn bond frac.', 'Ac - Mo bond frac.', 'Ac - N bond frac.', 'Ac - Na bond frac.', 'Ac - Nb bond frac.', 'Ac - Nd bond frac.', 'Ac - Ni bond frac.', 'Ac - Np bond frac.', 'Ac - O bond frac.', 'Ac - Pa bond frac.', 'Ac - Pb bond frac.', 'Ac - Pd bond frac.', 'Ac - Pm bond frac.', 'Ac - Pr bond frac.', 'Ac - Rb bond frac.', 'Ac - Rh bond frac.', 'Ac - Ru bond frac.', 'Ac - S bond frac.', 'Ac - Sb bond frac.', 'Ac - Sc bond frac.', 'Ac - Se bond frac.', 'Ac - Si bond frac.', 'Ac - Sm bond frac.', 'Ac - Sn bond frac.', 'Ac - Sr bond frac.', 'Ac - Tb bond frac.', 'Ac - Te bond frac.', 'Ac - Th bond frac.', 'Ac - Ti bond frac.', 'Ac - Tl bond frac.', 'Ac - Tm bond frac.', 'Ac - V bond frac.', 'Ac - Y bond frac.', 'Ac - Yb bond frac.', 'Ac - Zn bond frac.', 'Ac - Zr bond frac.', 'Ag - Ag bond frac.', 'Ag - Al bond frac.', 'Ag - As bond frac.', 'Ag - Au bond frac.', 'Ag - B bond frac.', 'Ag - Ba bond frac.', 'Ag - Be bond frac.', 'Ag - Bi bond frac.', 'Ag - Br bond frac.', 'Ag - C bond frac.', 'Ag - Ca bond frac.', 'Ag - Cd bond frac.', 'Ag - Ce bond frac.', 'Ag - Cl bond frac.', 'Ag - Co bond frac.', 'Ag - Cr bond frac.', 'Ag - Cs bond frac.', 'Ag - Cu bond frac.', 'Ag - Dy bond frac.', 'Ag - Er bond frac.', 'Ag - Eu bond frac.', 'Ag - F bond frac.', 'Ag - Fe bond frac.', 'Ag - Ga bond frac.', 'Ag - Gd bond frac.', 'Ag - Ge bond frac.', 'Ag - H bond frac.', 'Ag - Hf bond frac.', 'Ag - Hg bond frac.', 'Ag - Ho bond frac.', 'Ag - I bond frac.', 'Ag - In bond frac.', 'Ag - Ir bond frac.', 'Ag - K bond frac.', 'Ag - La bond frac.', 'Ag - Li bond frac.', 'Ag - Lu bond frac.', 'Ag - Mg bond frac.', 'Ag - Mn bond frac.', 'Ag - Mo bond frac.', 'Ag - N bond frac.', 'Ag - Na bond frac.', 'Ag - Nb bond frac.', 'Ag - Nd bond frac.', 'Ag - Ni bond frac.', 'Ag - Np bond frac.', 'Ag - O bond frac.', 'Ag - Os bond frac.', 'Ag - P bond frac.', 'Ag - Pa bond frac.', 'Ag - Pb bond frac.', 'Ag - Pd bond frac.', 'Ag - Pm bond frac.', 'Ag - Pr bond frac.', 'Ag - Pt bond frac.', 'Ag - Pu bond frac.', 'Ag - Rb bond frac.', 'Ag - Re bond frac.', 'Ag - Rh bond frac.', 'Ag - Ru bond frac.', 'Ag - S bond frac.', 'Ag - Sb bond frac.', 'Ag - Sc bond frac.', 'Ag - Se bond frac.', 'Ag - Si bond frac.', 'Ag - Sm bond frac.', 'Ag - Sn bond frac.', 'Ag - Sr bond frac.', 'Ag - Ta bond frac.', 'Ag - Tb bond frac.', 'Ag - Tc bond frac.', 'Ag - Te bond frac.', 'Ag - Th bond frac.', 'Ag - Ti bond frac.', 'Ag - Tl bond frac.', 'Ag - Tm bond frac.', 'Ag - U bond frac.', 'Ag - V bond frac.', 'Ag - W bond frac.', 'Ag - Xe bond frac.', 'Ag - Y bond frac.', 'Ag - Yb bond frac.', 'Ag - Zn bond frac.', 'Ag - Zr bond frac.', 'Al - Al bond frac.', 'Al - As bond frac.', 'Al - Au bond frac.', 'Al - B bond frac.', 'Al - Ba bond frac.', 'Al - Be bond frac.', 'Al - Bi bond frac.', 'Al - Br bond frac.', 'Al - C bond frac.', 'Al - Ca bond frac.', 'Al - Cd bond frac.', 'Al - Ce bond frac.', 'Al - Cl bond frac.', 'Al - Co bond frac.', 'Al - Cr bond frac.', 'Al - Cs bond frac.', 'Al - Cu bond frac.', 'Al - Dy bond frac.', 'Al - Er bond frac.', 'Al - Eu bond frac.', 'Al - F bond frac.', 'Al - Fe bond frac.', 'Al - Ga bond frac.', 'Al - Gd bond frac.', 'Al - Ge bond frac.', 'Al - H bond frac.', 'Al - Hf bond frac.', 'Al - Hg bond frac.', 'Al - Ho bond frac.', 'Al - I bond frac.', 'Al - In bond frac.', 'Al - Ir bond frac.', 'Al - K bond frac.', 'Al - La bond frac.', 'Al - Li bond frac.', 'Al - Lu bond frac.', 'Al - Mg bond frac.', 'Al - Mn bond frac.', 'Al - Mo bond frac.', 'Al - N bond frac.', 'Al - Na bond frac.', 'Al - Nb bond frac.', 'Al - Nd bond frac.', 'Al - Ni bond frac.', 'Al - Np bond frac.', 'Al - O bond frac.', 'Al - Os bond frac.', 'Al - P bond frac.', 'Al - Pa bond frac.', 'Al - Pb bond frac.', 'Al - Pd bond frac.', 'Al - Pm bond frac.', 'Al - Pr bond frac.', 'Al - Pt bond frac.', 'Al - Pu bond frac.', 'Al - Rb bond frac.', 'Al - Re bond frac.', 'Al - Rh bond frac.', 'Al - Ru bond frac.', 'Al - S bond frac.', 'Al - Sb bond frac.', 'Al - Sc bond frac.', 'Al - Se bond frac.', 'Al - Si bond frac.', 'Al - Sm bond frac.', 'Al - Sn bond frac.', 'Al - Sr bond frac.', 'Al - Ta bond frac.', 'Al - Tb bond frac.', 'Al - Tc bond frac.', 'Al - Te bond frac.', 'Al - Th bond frac.', 'Al - Ti bond frac.', 'Al - Tl bond frac.', 'Al - Tm bond frac.', 'Al - U bond frac.', 'Al - V bond frac.', 'Al - W bond frac.', 'Al - Y bond frac.', 'Al - Yb bond frac.', 'Al - Zn bond frac.', 'Al - Zr bond frac.', 'Ar - Ar bond frac.', 'As - As bond frac.', 'As - Au bond frac.', 'As - B bond frac.', 'As - Ba bond frac.', 'As - Be bond frac.', 'As - Bi bond frac.', 'As - Br bond frac.', 'As - C bond frac.', 'As - Ca bond frac.', 'As - Cd bond frac.', 'As - Ce bond frac.', 'As - Cl bond frac.', 'As - Co bond frac.', 'As - Cr bond frac.', 'As - Cs bond frac.', 'As - Cu bond frac.', 'As - Dy bond frac.', 'As - Er bond frac.', 'As - Eu bond frac.', 'As - F bond frac.', 'As - Fe bond frac.', 'As - Ga bond frac.', 'As - Gd bond frac.', 'As - Ge bond frac.', 'As - H bond frac.', 'As - Hf bond frac.', 'As - Hg bond frac.', 'As - Ho bond frac.', 'As - I bond frac.', 'As - In bond frac.', 'As - Ir bond frac.', 'As - K bond frac.', 'As - Kr bond frac.', 'As - La bond frac.', 'As - Li bond frac.', 'As - Lu bond frac.', 'As - Mg bond frac.', 'As - Mn bond frac.', 'As - Mo bond frac.', 'As - N bond frac.', 'As - Na bond frac.', 'As - Nb bond frac.', 'As - Nd bond frac.', 'As - Ni bond frac.', 'As - Np bond frac.', 'As - O bond frac.', 'As - Os bond frac.', 'As - P bond frac.', 'As - Pa bond frac.', 'As - Pb bond frac.', 'As - Pd bond frac.', 'As - Pm bond frac.', 'As - Pr bond frac.', 'As - Pt bond frac.', 'As - Pu bond frac.', 'As - Rb bond frac.', 'As - Re bond frac.', 'As - Rh bond frac.', 'As - Ru bond frac.', 'As - S bond frac.', 'As - Sb bond frac.', 'As - Sc bond frac.', 'As - Se bond frac.', 'As - Si bond frac.', 'As - Sm bond frac.', 'As - Sn bond frac.', 'As - Sr bond frac.', 'As - Ta bond frac.', 'As - Tb bond frac.', 'As - Tc bond frac.', 'As - Te bond frac.', 'As - Th bond frac.', 'As - Ti bond frac.', 'As - Tl bond frac.', 'As - Tm bond frac.', 'As - U bond frac.', 'As - V bond frac.', 'As - W bond frac.', 'As - Xe bond frac.', 'As - Y bond frac.', 'As - Yb bond frac.', 'As - Zn bond frac.', 'As - Zr bond frac.', 'Au - Au bond frac.', 'Au - B bond frac.', 'Au - Ba bond frac.', 'Au - Be bond frac.', 'Au - Bi bond frac.', 'Au - Br bond frac.', 'Au - C bond frac.', 'Au - Ca bond frac.', 'Au - Cd bond frac.', 'Au - Ce bond frac.', 'Au - Cl bond frac.', 'Au - Co bond frac.', 'Au - Cr bond frac.', 'Au - Cs bond frac.', 'Au - Cu bond frac.', 'Au - Dy bond frac.', 'Au - Er bond frac.', 'Au - Eu bond frac.', 'Au - F bond frac.', 'Au - Fe bond frac.', 'Au - Ga bond frac.', 'Au - Gd bond frac.', 'Au - Ge bond frac.', 'Au - H bond frac.', 'Au - Hf bond frac.', 'Au - Hg bond frac.', 'Au - Ho bond frac.', 'Au - I bond frac.', 'Au - In bond frac.', 'Au - Ir bond frac.', 'Au - K bond frac.', 'Au - La bond frac.', 'Au - Li bond frac.', 'Au - Lu bond frac.', 'Au - Mg bond frac.', 'Au - Mn bond frac.', 'Au - Mo bond frac.', 'Au - N bond frac.', 'Au - Na bond frac.', 'Au - Nb bond frac.', 'Au - Nd bond frac.', 'Au - Ni bond frac.', 'Au - Np bond frac.', 'Au - O bond frac.', 'Au - Os bond frac.', 'Au - P bond frac.', 'Au - Pa bond frac.', 'Au - Pb bond frac.', 'Au - Pd bond frac.', 'Au - Pm bond frac.', 'Au - Pr bond frac.', 'Au - Pt bond frac.', 'Au - Pu bond frac.', 'Au - Rb bond frac.', 'Au - Re bond frac.', 'Au - Rh bond frac.', 'Au - Ru bond frac.', 'Au - S bond frac.', 'Au - Sb bond frac.', 'Au - Sc bond frac.', 'Au - Se bond frac.', 'Au - Si bond frac.', 'Au - Sm bond frac.', 'Au - Sn bond frac.', 'Au - Sr bond frac.', 'Au - Ta bond frac.', 'Au - Tb bond frac.', 'Au - Tc bond frac.', 'Au - Te bond frac.', 'Au - Th bond frac.', 'Au - Ti bond frac.', 'Au - Tl bond frac.', 'Au - Tm bond frac.', 'Au - U bond frac.', 'Au - V bond frac.', 'Au - W bond frac.', 'Au - Xe bond frac.', 'Au - Y bond frac.', 'Au - Yb bond frac.', 'Au - Zn bond frac.', 'Au - Zr bond frac.', 'B - B bond frac.', 'B - Ba bond frac.', 'B - Be bond frac.', 'B - Bi bond frac.', 'B - Br bond frac.', 'B - C bond frac.', 'B - Ca bond frac.', 'B - Cd bond frac.', 'B - Ce bond frac.', 'B - Cl bond frac.', 'B - Co bond frac.', 'B - Cr bond frac.', 'B - Cs bond frac.', 'B - Cu bond frac.', 'B - Dy bond frac.', 'B - Er bond frac.', 'B - Eu bond frac.', 'B - F bond frac.', 'B - Fe bond frac.', 'B - Ga bond frac.', 'B - Gd bond frac.', 'B - Ge bond frac.', 'B - H bond frac.', 'B - Hf bond frac.', 'B - Hg bond frac.', 'B - Ho bond frac.', 'B - I bond frac.', 'B - In bond frac.', 'B - Ir bond frac.', 'B - K bond frac.', 'B - La bond frac.', 'B - Li bond frac.', 'B - Lu bond frac.', 'B - Mg bond frac.', 'B - Mn bond frac.', 'B - Mo bond frac.', 'B - N bond frac.', 'B - Na bond frac.', 'B - Nb bond frac.', 'B - Nd bond frac.', 'B - Ni bond frac.', 'B - Np bond frac.', 'B - O bond frac.', 'B - Os bond frac.', 'B - P bond frac.', 'B - Pa bond frac.', 'B - Pb bond frac.', 'B - Pd bond frac.', 'B - Pm bond frac.', 'B - Pr bond frac.', 'B - Pt bond frac.', 'B - Pu bond frac.', 'B - Rb bond frac.', 'B - Re bond frac.', 'B - Rh bond frac.', 'B - Ru bond frac.', 'B - S bond frac.', 'B - Sb bond frac.', 'B - Sc bond frac.', 'B - Se bond frac.', 'B - Si bond frac.', 'B - Sm bond frac.', 'B - Sn bond frac.', 'B - Sr bond frac.', 'B - Ta bond frac.', 'B - Tb bond frac.', 'B - Tc bond frac.', 'B - Te bond frac.', 'B - Th bond frac.', 'B - Ti bond frac.', 'B - Tl bond frac.', 'B - Tm bond frac.', 'B - U bond frac.', 'B - V bond frac.', 'B - W bond frac.', 'B - Xe bond frac.', 'B - Y bond frac.', 'B - Yb bond frac.', 'B - Zn bond frac.', 'B - Zr bond frac.', 'Ba - Ba bond frac.', 'Ba - Be bond frac.', 'Ba - Bi bond frac.', 'Ba - Br bond frac.', 'Ba - C bond frac.', 'Ba - Ca bond frac.', 'Ba - Cd bond frac.', 'Ba - Ce bond frac.', 'Ba - Cl bond frac.', 'Ba - Co bond frac.', 'Ba - Cr bond frac.', 'Ba - Cs bond frac.', 'Ba - Cu bond frac.', 'Ba - Dy bond frac.', 'Ba - Er bond frac.', 'Ba - Eu bond frac.', 'Ba - F bond frac.', 'Ba - Fe bond frac.', 'Ba - Ga bond frac.', 'Ba - Gd bond frac.', 'Ba - Ge bond frac.', 'Ba - H bond frac.', 'Ba - Hf bond frac.', 'Ba - Hg bond frac.', 'Ba - Ho bond frac.', 'Ba - I bond frac.', 'Ba - In bond frac.', 'Ba - Ir bond frac.', 'Ba - K bond frac.', 'Ba - La bond frac.', 'Ba - Li bond frac.', 'Ba - Lu bond frac.', 'Ba - Mg bond frac.', 'Ba - Mn bond frac.', 'Ba - Mo bond frac.', 'Ba - N bond frac.', 'Ba - Na bond frac.', 'Ba - Nb bond frac.', 'Ba - Nd bond frac.', 'Ba - Ni bond frac.', 'Ba - Np bond frac.', 'Ba - O bond frac.', 'Ba - Os bond frac.', 'Ba - P bond frac.', 'Ba - Pa bond frac.', 'Ba - Pb bond frac.', 'Ba - Pd bond frac.', 'Ba - Pm bond frac.', 'Ba - Pr bond frac.', 'Ba - Pt bond frac.', 'Ba - Pu bond frac.', 'Ba - Rb bond frac.', 'Ba - Re bond frac.', 'Ba - Rh bond frac.', 'Ba - Ru bond frac.', 'Ba - S bond frac.', 'Ba - Sb bond frac.', 'Ba - Sc bond frac.', 'Ba - Se bond frac.', 'Ba - Si bond frac.', 'Ba - Sm bond frac.', 'Ba - Sn bond frac.', 'Ba - Sr bond frac.', 'Ba - Ta bond frac.', 'Ba - Tb bond frac.', 'Ba - Tc bond frac.', 'Ba - Te bond frac.', 'Ba - Th bond frac.', 'Ba - Ti bond frac.', 'Ba - Tl bond frac.', 'Ba - Tm bond frac.', 'Ba - U bond frac.', 'Ba - V bond frac.', 'Ba - W bond frac.', 'Ba - Xe bond frac.', 'Ba - Y bond frac.', 'Ba - Yb bond frac.', 'Ba - Zn bond frac.', 'Ba - Zr bond frac.', 'Be - Be bond frac.', 'Be - Bi bond frac.', 'Be - Br bond frac.', 'Be - C bond frac.', 'Be - Ca bond frac.', 'Be - Cd bond frac.', 'Be - Ce bond frac.', 'Be - Cl bond frac.', 'Be - Co bond frac.', 'Be - Cr bond frac.', 'Be - Cs bond frac.', 'Be - Cu bond frac.', 'Be - Dy bond frac.', 'Be - Er bond frac.', 'Be - Eu bond frac.', 'Be - F bond frac.', 'Be - Fe bond frac.', 'Be - Ga bond frac.', 'Be - Gd bond frac.', 'Be - Ge bond frac.', 'Be - H bond frac.', 'Be - Hf bond frac.', 'Be - Hg bond frac.', 'Be - Ho bond frac.', 'Be - I bond frac.', 'Be - In bond frac.', 'Be - Ir bond frac.', 'Be - K bond frac.', 'Be - La bond frac.', 'Be - Li bond frac.', 'Be - Lu bond frac.', 'Be - Mg bond frac.', 'Be - Mn bond frac.', 'Be - Mo bond frac.', 'Be - N bond frac.', 'Be - Na bond frac.', 'Be - Nb bond frac.', 'Be - Nd bond frac.', 'Be - Ni bond frac.', 'Be - Np bond frac.', 'Be - O bond frac.', 'Be - Os bond frac.', 'Be - P bond frac.', 'Be - Pa bond frac.', 'Be - Pb bond frac.', 'Be - Pd bond frac.', 'Be - Pm bond frac.', 'Be - Pr bond frac.', 'Be - Pt bond frac.', 'Be - Pu bond frac.', 'Be - Rb bond frac.', 'Be - Re bond frac.', 'Be - Rh bond frac.', 'Be - Ru bond frac.', 'Be - S bond frac.', 'Be - Sb bond frac.', 'Be - Sc bond frac.', 'Be - Se bond frac.', 'Be - Si bond frac.', 'Be - Sm bond frac.', 'Be - Sn bond frac.', 'Be - Sr bond frac.', 'Be - Ta bond frac.', 'Be - Tb bond frac.', 'Be - Tc bond frac.', 'Be - Te bond frac.', 'Be - Th bond frac.', 'Be - Ti bond frac.', 'Be - Tl bond frac.', 'Be - Tm bond frac.', 'Be - U bond frac.', 'Be - V bond frac.', 'Be - W bond frac.', 'Be - Y bond frac.', 'Be - Yb bond frac.', 'Be - Zn bond frac.', 'Be - Zr bond frac.', 'Bi - Bi bond frac.', 'Bi - Br bond frac.', 'Bi - C bond frac.', 'Bi - Ca bond frac.', 'Bi - Cd bond frac.', 'Bi - Ce bond frac.', 'Bi - Cl bond frac.', 'Bi - Co bond frac.', 'Bi - Cr bond frac.', 'Bi - Cs bond frac.', 'Bi - Cu bond frac.', 'Bi - Dy bond frac.', 'Bi - Er bond frac.', 'Bi - Eu bond frac.', 'Bi - F bond frac.', 'Bi - Fe bond frac.', 'Bi - Ga bond frac.', 'Bi - Gd bond frac.', 'Bi - Ge bond frac.', 'Bi - H bond frac.', 'Bi - Hf bond frac.', 'Bi - Hg bond frac.', 'Bi - Ho bond frac.', 'Bi - I bond frac.', 'Bi - In bond frac.', 'Bi - Ir bond frac.', 'Bi - K bond frac.', 'Bi - Kr bond frac.', 'Bi - La bond frac.', 'Bi - Li bond frac.', 'Bi - Lu bond frac.', 'Bi - Mg bond frac.', 'Bi - Mn bond frac.', 'Bi - Mo bond frac.', 'Bi - N bond frac.', 'Bi - Na bond frac.', 'Bi - Nb bond frac.', 'Bi - Nd bond frac.', 'Bi - Ni bond frac.', 'Bi - Np bond frac.', 'Bi - O bond frac.', 'Bi - Os bond frac.', 'Bi - P bond frac.', 'Bi - Pa bond frac.', 'Bi - Pb bond frac.', 'Bi - Pd bond frac.', 'Bi - Pm bond frac.', 'Bi - Pr bond frac.', 'Bi - Pt bond frac.', 'Bi - Pu bond frac.', 'Bi - Rb bond frac.', 'Bi - Re bond frac.', 'Bi - Rh bond frac.', 'Bi - Ru bond frac.', 'Bi - S bond frac.', 'Bi - Sb bond frac.', 'Bi - Sc bond frac.', 'Bi - Se bond frac.', 'Bi - Si bond frac.', 'Bi - Sm bond frac.', 'Bi - Sn bond frac.', 'Bi - Sr bond frac.', 'Bi - Ta bond frac.', 'Bi - Tb bond frac.', 'Bi - Tc bond frac.', 'Bi - Te bond frac.', 'Bi - Th bond frac.', 'Bi - Ti bond frac.', 'Bi - Tl bond frac.', 'Bi - Tm bond frac.', 'Bi - U bond frac.', 'Bi - V bond frac.', 'Bi - W bond frac.', 'Bi - Xe bond frac.', 'Bi - Y bond frac.', 'Bi - Yb bond frac.', 'Bi - Zn bond frac.', 'Bi - Zr bond frac.', 'Br - Br bond frac.', 'Br - C bond frac.', 'Br - Ca bond frac.', 'Br - Cd bond frac.', 'Br - Ce bond frac.', 'Br - Cl bond frac.', 'Br - Co bond frac.', 'Br - Cr bond frac.', 'Br - Cs bond frac.', 'Br - Cu bond frac.', 'Br - Dy bond frac.', 'Br - Er bond frac.', 'Br - Eu bond frac.', 'Br - F bond frac.', 'Br - Fe bond frac.', 'Br - Ga bond frac.', 'Br - Gd bond frac.', 'Br - Ge bond frac.', 'Br - H bond frac.', 'Br - Hf bond frac.', 'Br - Hg bond frac.', 'Br - Ho bond frac.', 'Br - I bond frac.', 'Br - In bond frac.', 'Br - Ir bond frac.', 'Br - K bond frac.', 'Br - Kr bond frac.', 'Br - La bond frac.', 'Br - Li bond frac.', 'Br - Lu bond frac.', 'Br - Mg bond frac.', 'Br - Mn bond frac.', 'Br - Mo bond frac.', 'Br - N bond frac.', 'Br - Na bond frac.', 'Br - Nb bond frac.', 'Br - Nd bond frac.', 'Br - Ni bond frac.', 'Br - Np bond frac.', 'Br - O bond frac.', 'Br - Os bond frac.', 'Br - P bond frac.', 'Br - Pa bond frac.', 'Br - Pb bond frac.', 'Br - Pd bond frac.', 'Br - Pm bond frac.', 'Br - Pr bond frac.', 'Br - Pt bond frac.', 'Br - Pu bond frac.', 'Br - Rb bond frac.', 'Br - Re bond frac.', 'Br - Rh bond frac.', 'Br - Ru bond frac.', 'Br - S bond frac.', 'Br - Sb bond frac.', 'Br - Sc bond frac.', 'Br - Se bond frac.', 'Br - Si bond frac.', 'Br - Sm bond frac.', 'Br - Sn bond frac.', 'Br - Sr bond frac.', 'Br - Ta bond frac.', 'Br - Tb bond frac.', 'Br - Tc bond frac.', 'Br - Te bond frac.', 'Br - Th bond frac.', 'Br - Ti bond frac.', 'Br - Tl bond frac.', 'Br - Tm bond frac.', 'Br - U bond frac.', 'Br - V bond frac.', 'Br - W bond frac.', 'Br - Xe bond frac.', 'Br - Y bond frac.', 'Br - Yb bond frac.', 'Br - Zn bond frac.', 'Br - Zr bond frac.', 'C - C bond frac.', 'C - Ca bond frac.', 'C - Cd bond frac.', 'C - Ce bond frac.', 'C - Cl bond frac.', 'C - Co bond frac.', 'C - Cr bond frac.', 'C - Cs bond frac.', 'C - Cu bond frac.', 'C - Dy bond frac.', 'C - Er bond frac.', 'C - Eu bond frac.', 'C - F bond frac.', 'C - Fe bond frac.', 'C - Ga bond frac.', 'C - Gd bond frac.', 'C - Ge bond frac.', 'C - H bond frac.', 'C - Hf bond frac.', 'C - Hg bond frac.', 'C - Ho bond frac.', 'C - I bond frac.', 'C - In bond frac.', 'C - Ir bond frac.', 'C - K bond frac.', 'C - La bond frac.', 'C - Li bond frac.', 'C - Lu bond frac.', 'C - Mg bond frac.', 'C - Mn bond frac.', 'C - Mo bond frac.', 'C - N bond frac.', 'C - Na bond frac.', 'C - Nb bond frac.', 'C - Nd bond frac.', 'C - Ni bond frac.', 'C - Np bond frac.', 'C - O bond frac.', 'C - Os bond frac.', 'C - P bond frac.', 'C - Pa bond frac.', 'C - Pb bond frac.', 'C - Pd bond frac.', 'C - Pr bond frac.', 'C - Pt bond frac.', 'C - Pu bond frac.', 'C - Rb bond frac.', 'C - Re bond frac.', 'C - Rh bond frac.', 'C - Ru bond frac.', 'C - S bond frac.', 'C - Sb bond frac.', 'C - Sc bond frac.', 'C - Se bond frac.', 'C - Si bond frac.', 'C - Sm bond frac.', 'C - Sn bond frac.', 'C - Sr bond frac.', 'C - Ta bond frac.', 'C - Tb bond frac.', 'C - Tc bond frac.', 'C - Te bond frac.', 'C - Th bond frac.', 'C - Ti bond frac.', 'C - Tl bond frac.', 'C - Tm bond frac.', 'C - U bond frac.', 'C - V bond frac.', 'C - W bond frac.', 'C - Xe bond frac.', 'C - Y bond frac.', 'C - Yb bond frac.', 'C - Zn bond frac.', 'C - Zr bond frac.', 'Ca - Ca bond frac.', 'Ca - Cd bond frac.', 'Ca - Ce bond frac.', 'Ca - Cl bond frac.', 'Ca - Co bond frac.', 'Ca - Cr bond frac.', 'Ca - Cs bond frac.', 'Ca - Cu bond frac.', 'Ca - Dy bond frac.', 'Ca - Er bond frac.', 'Ca - Eu bond frac.', 'Ca - F bond frac.', 'Ca - Fe bond frac.', 'Ca - Ga bond frac.', 'Ca - Gd bond frac.', 'Ca - Ge bond frac.', 'Ca - H bond frac.', 'Ca - Hf bond frac.', 'Ca - Hg bond frac.', 'Ca - Ho bond frac.', 'Ca - I bond frac.', 'Ca - In bond frac.', 'Ca - Ir bond frac.', 'Ca - K bond frac.', 'Ca - La bond frac.', 'Ca - Li bond frac.', 'Ca - Lu bond frac.', 'Ca - Mg bond frac.', 'Ca - Mn bond frac.', 'Ca - Mo bond frac.', 'Ca - N bond frac.', 'Ca - Na bond frac.', 'Ca - Nb bond frac.', 'Ca - Nd bond frac.', 'Ca - Ni bond frac.', 'Ca - Np bond frac.', 'Ca - O bond frac.', 'Ca - Os bond frac.', 'Ca - P bond frac.', 'Ca - Pb bond frac.', 'Ca - Pd bond frac.', 'Ca - Pm bond frac.', 'Ca - Pr bond frac.', 'Ca - Pt bond frac.', 'Ca - Pu bond frac.', 'Ca - Rb bond frac.', 'Ca - Re bond frac.', 'Ca - Rh bond frac.', 'Ca - Ru bond frac.', 'Ca - S bond frac.', 'Ca - Sb bond frac.', 'Ca - Sc bond frac.', 'Ca - Se bond frac.', 'Ca - Si bond frac.', 'Ca - Sm bond frac.', 'Ca - Sn bond frac.', 'Ca - Sr bond frac.', 'Ca - Ta bond frac.', 'Ca - Tb bond frac.', 'Ca - Tc bond frac.', 'Ca - Te bond frac.', 'Ca - Th bond frac.', 'Ca - Ti bond frac.', 'Ca - Tl bond frac.', 'Ca - Tm bond frac.', 'Ca - U bond frac.', 'Ca - V bond frac.', 'Ca - W bond frac.', 'Ca - Xe bond frac.', 'Ca - Y bond frac.', 'Ca - Yb bond frac.', 'Ca - Zn bond frac.', 'Ca - Zr bond frac.', 'Cd - Cd bond frac.', 'Cd - Ce bond frac.', 'Cd - Cl bond frac.', 'Cd - Co bond frac.', 'Cd - Cr bond frac.', 'Cd - Cs bond frac.', 'Cd - Cu bond frac.', 'Cd - Dy bond frac.', 'Cd - Er bond frac.', 'Cd - Eu bond frac.', 'Cd - F bond frac.', 'Cd - Fe bond frac.', 'Cd - Ga bond frac.', 'Cd - Gd bond frac.', 'Cd - Ge bond frac.', 'Cd - H bond frac.', 'Cd - Hf bond frac.', 'Cd - Hg bond frac.', 'Cd - Ho bond frac.', 'Cd - I bond frac.', 'Cd - In bond frac.', 'Cd - Ir bond frac.', 'Cd - K bond frac.', 'Cd - La bond frac.', 'Cd - Li bond frac.', 'Cd - Lu bond frac.', 'Cd - Mg bond frac.', 'Cd - Mn bond frac.', 'Cd - Mo bond frac.', 'Cd - N bond frac.', 'Cd - Na bond frac.', 'Cd - Nb bond frac.', 'Cd - Nd bond frac.', 'Cd - Ni bond frac.', 'Cd - Np bond frac.', 'Cd - O bond frac.', 'Cd - Os bond frac.', 'Cd - P bond frac.', 'Cd - Pa bond frac.', 'Cd - Pb bond frac.', 'Cd - Pd bond frac.', 'Cd - Pm bond frac.', 'Cd - Pr bond frac.', 'Cd - Pt bond frac.', 'Cd - Pu bond frac.', 'Cd - Rb bond frac.', 'Cd - Re bond frac.', 'Cd - Rh bond frac.', 'Cd - Ru bond frac.', 'Cd - S bond frac.', 'Cd - Sb bond frac.', 'Cd - Sc bond frac.', 'Cd - Se bond frac.', 'Cd - Si bond frac.', 'Cd - Sm bond frac.', 'Cd - Sn bond frac.', 'Cd - Sr bond frac.', 'Cd - Ta bond frac.', 'Cd - Tb bond frac.', 'Cd - Tc bond frac.', 'Cd - Te bond frac.', 'Cd - Th bond frac.', 'Cd - Ti bond frac.', 'Cd - Tl bond frac.', 'Cd - Tm bond frac.', 'Cd - U bond frac.', 'Cd - V bond frac.', 'Cd - W bond frac.', 'Cd - Xe bond frac.', 'Cd - Y bond frac.', 'Cd - Yb bond frac.', 'Cd - Zn bond frac.', 'Cd - Zr bond frac.', 'Ce - Ce bond frac.', 'Ce - Cl bond frac.', 'Ce - Co bond frac.', 'Ce - Cr bond frac.', 'Ce - Cs bond frac.', 'Ce - Cu bond frac.', 'Ce - Dy bond frac.', 'Ce - Er bond frac.', 'Ce - Eu bond frac.', 'Ce - F bond frac.', 'Ce - Fe bond frac.', 'Ce - Ga bond frac.', 'Ce - Gd bond frac.', 'Ce - Ge bond frac.', 'Ce - H bond frac.', 'Ce - Hf bond frac.', 'Ce - Hg bond frac.', 'Ce - Ho bond frac.', 'Ce - I bond frac.', 'Ce - In bond frac.', 'Ce - Ir bond frac.', 'Ce - K bond frac.', 'Ce - La bond frac.', 'Ce - Li bond frac.', 'Ce - Lu bond frac.', 'Ce - Mg bond frac.', 'Ce - Mn bond frac.', 'Ce - Mo bond frac.', 'Ce - N bond frac.', 'Ce - Na bond frac.', 'Ce - Nb bond frac.', 'Ce - Nd bond frac.', 'Ce - Ni bond frac.', 'Ce - O bond frac.', 'Ce - Os bond frac.', 'Ce - P bond frac.', 'Ce - Pa bond frac.', 'Ce - Pb bond frac.', 'Ce - Pd bond frac.', 'Ce - Pm bond frac.', 'Ce - Pr bond frac.', 'Ce - Pt bond frac.', 'Ce - Pu bond frac.', 'Ce - Rb bond frac.', 'Ce - Re bond frac.', 'Ce - Rh bond frac.', 'Ce - Ru bond frac.', 'Ce - S bond frac.', 'Ce - Sb bond frac.', 'Ce - Sc bond frac.', 'Ce - Se bond frac.', 'Ce - Si bond frac.', 'Ce - Sm bond frac.', 'Ce - Sn bond frac.', 'Ce - Sr bond frac.', 'Ce - Ta bond frac.', 'Ce - Tb bond frac.', 'Ce - Te bond frac.', 'Ce - Th bond frac.', 'Ce - Ti bond frac.', 'Ce - Tl bond frac.', 'Ce - Tm bond frac.', 'Ce - U bond frac.', 'Ce - V bond frac.', 'Ce - W bond frac.', 'Ce - Y bond frac.', 'Ce - Yb bond frac.', 'Ce - Zn bond frac.', 'Ce - Zr bond frac.', 'Cl - Cl bond frac.', 'Cl - Co bond frac.', 'Cl - Cr bond frac.', 'Cl - Cs bond frac.', 'Cl - Cu bond frac.', 'Cl - Dy bond frac.', 'Cl - Er bond frac.', 'Cl - Eu bond frac.', 'Cl - F bond frac.', 'Cl - Fe bond frac.', 'Cl - Ga bond frac.', 'Cl - Gd bond frac.', 'Cl - Ge bond frac.', 'Cl - H bond frac.', 'Cl - Hf bond frac.', 'Cl - Hg bond frac.', 'Cl - Ho bond frac.', 'Cl - I bond frac.', 'Cl - In bond frac.', 'Cl - Ir bond frac.', 'Cl - K bond frac.', 'Cl - La bond frac.', 'Cl - Li bond frac.', 'Cl - Lu bond frac.', 'Cl - Mg bond frac.', 'Cl - Mn bond frac.', 'Cl - Mo bond frac.', 'Cl - N bond frac.', 'Cl - Na bond frac.', 'Cl - Nb bond frac.', 'Cl - Nd bond frac.', 'Cl - Ni bond frac.', 'Cl - Np bond frac.', 'Cl - O bond frac.', 'Cl - Os bond frac.', 'Cl - P bond frac.', 'Cl - Pa bond frac.', 'Cl - Pb bond frac.', 'Cl - Pd bond frac.', 'Cl - Pm bond frac.', 'Cl - Pr bond frac.', 'Cl - Pt bond frac.', 'Cl - Pu bond frac.', 'Cl - Rb bond frac.', 'Cl - Re bond frac.', 'Cl - Rh bond frac.', 'Cl - Ru bond frac.', 'Cl - S bond frac.', 'Cl - Sb bond frac.', 'Cl - Sc bond frac.', 'Cl - Se bond frac.', 'Cl - Si bond frac.', 'Cl - Sm bond frac.', 'Cl - Sn bond frac.', 'Cl - Sr bond frac.', 'Cl - Ta bond frac.', 'Cl - Tb bond frac.', 'Cl - Tc bond frac.', 'Cl - Te bond frac.', 'Cl - Th bond frac.', 'Cl - Ti bond frac.', 'Cl - Tl bond frac.', 'Cl - Tm bond frac.', 'Cl - U bond frac.', 'Cl - V bond frac.', 'Cl - W bond frac.', 'Cl - Xe bond frac.', 'Cl - Y bond frac.', 'Cl - Yb bond frac.', 'Cl - Zn bond frac.', 'Cl - Zr bond frac.', 'Co - Co bond frac.', 'Co - Cr bond frac.', 'Co - Cs bond frac.', 'Co - Cu bond frac.', 'Co - Dy bond frac.', 'Co - Er bond frac.', 'Co - Eu bond frac.', 'Co - F bond frac.', 'Co - Fe bond frac.', 'Co - Ga bond frac.', 'Co - Gd bond frac.', 'Co - Ge bond frac.', 'Co - H bond frac.', 'Co - Hf bond frac.', 'Co - Hg bond frac.', 'Co - Ho bond frac.', 'Co - I bond frac.', 'Co - In bond frac.', 'Co - Ir bond frac.', 'Co - K bond frac.', 'Co - La bond frac.', 'Co - Li bond frac.', 'Co - Lu bond frac.', 'Co - Mg bond frac.', 'Co - Mn bond frac.', 'Co - Mo bond frac.', 'Co - N bond frac.', 'Co - Na bond frac.', 'Co - Nb bond frac.', 'Co - Nd bond frac.', 'Co - Ni bond frac.', 'Co - Np bond frac.', 'Co - O bond frac.', 'Co - Os bond frac.', 'Co - P bond frac.', 'Co - Pa bond frac.', 'Co - Pb bond frac.', 'Co - Pd bond frac.', 'Co - Pm bond frac.', 'Co - Pr bond frac.', 'Co - Pt bond frac.', 'Co - Pu bond frac.', 'Co - Rb bond frac.', 'Co - Re bond frac.', 'Co - Rh bond frac.', 'Co - Ru bond frac.', 'Co - S bond frac.', 'Co - Sb bond frac.', 'Co - Sc bond frac.', 'Co - Se bond frac.', 'Co - Si bond frac.', 'Co - Sm bond frac.', 'Co - Sn bond frac.', 'Co - Sr bond frac.', 'Co - Ta bond frac.', 'Co - Tb bond frac.', 'Co - Tc bond frac.', 'Co - Te bond frac.', 'Co - Th bond frac.', 'Co - Ti bond frac.', 'Co - Tl bond frac.', 'Co - Tm bond frac.', 'Co - U bond frac.', 'Co - V bond frac.', 'Co - W bond frac.', 'Co - Xe bond frac.', 'Co - Y bond frac.', 'Co - Yb bond frac.', 'Co - Zn bond frac.', 'Co - Zr bond frac.', 'Cr - Cr bond frac.', 'Cr - Cs bond frac.', 'Cr - Cu bond frac.', 'Cr - Dy bond frac.', 'Cr - Er bond frac.', 'Cr - Eu bond frac.', 'Cr - F bond frac.', 'Cr - Fe bond frac.', 'Cr - Ga bond frac.', 'Cr - Gd bond frac.', 'Cr - Ge bond frac.', 'Cr - H bond frac.', 'Cr - Hf bond frac.', 'Cr - Hg bond frac.', 'Cr - Ho bond frac.', 'Cr - I bond frac.', 'Cr - In bond frac.', 'Cr - Ir bond frac.', 'Cr - K bond frac.', 'Cr - La bond frac.', 'Cr - Li bond frac.', 'Cr - Lu bond frac.', 'Cr - Mg bond frac.', 'Cr - Mn bond frac.', 'Cr - Mo bond frac.', 'Cr - N bond frac.', 'Cr - Na bond frac.', 'Cr - Nb bond frac.', 'Cr - Nd bond frac.', 'Cr - Ni bond frac.', 'Cr - Np bond frac.', 'Cr - O bond frac.', 'Cr - Os bond frac.', 'Cr - P bond frac.', 'Cr - Pa bond frac.', 'Cr - Pb bond frac.', 'Cr - Pd bond frac.', 'Cr - Pm bond frac.', 'Cr - Pr bond frac.', 'Cr - Pt bond frac.', 'Cr - Pu bond frac.', 'Cr - Rb bond frac.', 'Cr - Re bond frac.', 'Cr - Rh bond frac.', 'Cr - Ru bond frac.', 'Cr - S bond frac.', 'Cr - Sb bond frac.', 'Cr - Sc bond frac.', 'Cr - Se bond frac.', 'Cr - Si bond frac.', 'Cr - Sm bond frac.', 'Cr - Sn bond frac.', 'Cr - Sr bond frac.', 'Cr - Ta bond frac.', 'Cr - Tb bond frac.', 'Cr - Tc bond frac.', 'Cr - Te bond frac.', 'Cr - Th bond frac.', 'Cr - Ti bond frac.', 'Cr - Tl bond frac.', 'Cr - Tm bond frac.', 'Cr - U bond frac.', 'Cr - V bond frac.', 'Cr - W bond frac.', 'Cr - Xe bond frac.', 'Cr - Y bond frac.', 'Cr - Yb bond frac.', 'Cr - Zn bond frac.', 'Cr - Zr bond frac.', 'Cs - Cs bond frac.', 'Cs - Cu bond frac.', 'Cs - Dy bond frac.', 'Cs - Er bond frac.', 'Cs - Eu bond frac.', 'Cs - F bond frac.', 'Cs - Fe bond frac.', 'Cs - Ga bond frac.', 'Cs - Gd bond frac.', 'Cs - Ge bond frac.', 'Cs - H bond frac.', 'Cs - Hf bond frac.', 'Cs - Hg bond frac.', 'Cs - Ho bond frac.', 'Cs - I bond frac.', 'Cs - In bond frac.', 'Cs - Ir bond frac.', 'Cs - K bond frac.', 'Cs - La bond frac.', 'Cs - Li bond frac.', 'Cs - Lu bond frac.', 'Cs - Mg bond frac.', 'Cs - Mn bond frac.', 'Cs - Mo bond frac.', 'Cs - N bond frac.', 'Cs - Na bond frac.', 'Cs - Nb bond frac.', 'Cs - Nd bond frac.', 'Cs - Ni bond frac.', 'Cs - Np bond frac.', 'Cs - O bond frac.', 'Cs - Os bond frac.', 'Cs - P bond frac.', 'Cs - Pa bond frac.', 'Cs - Pb bond frac.', 'Cs - Pd bond frac.', 'Cs - Pm bond frac.', 'Cs - Pr bond frac.', 'Cs - Pt bond frac.', 'Cs - Pu bond frac.', 'Cs - Rb bond frac.', 'Cs - Re bond frac.', 'Cs - Rh bond frac.', 'Cs - Ru bond frac.', 'Cs - S bond frac.', 'Cs - Sb bond frac.', 'Cs - Sc bond frac.', 'Cs - Se bond frac.', 'Cs - Si bond frac.', 'Cs - Sm bond frac.', 'Cs - Sn bond frac.', 'Cs - Sr bond frac.', 'Cs - Ta bond frac.', 'Cs - Tb bond frac.', 'Cs - Tc bond frac.', 'Cs - Te bond frac.', 'Cs - Th bond frac.', 'Cs - Ti bond frac.', 'Cs - Tl bond frac.', 'Cs - Tm bond frac.', 'Cs - U bond frac.', 'Cs - V bond frac.', 'Cs - W bond frac.', 'Cs - Xe bond frac.', 'Cs - Y bond frac.', 'Cs - Yb bond frac.', 'Cs - Zn bond frac.', 'Cs - Zr bond frac.', 'Cu - Cu bond frac.', 'Cu - Dy bond frac.', 'Cu - Er bond frac.', 'Cu - Eu bond frac.', 'Cu - F bond frac.', 'Cu - Fe bond frac.', 'Cu - Ga bond frac.', 'Cu - Gd bond frac.', 'Cu - Ge bond frac.', 'Cu - H bond frac.', 'Cu - Hf bond frac.', 'Cu - Hg bond frac.', 'Cu - Ho bond frac.', 'Cu - I bond frac.', 'Cu - In bond frac.', 'Cu - Ir bond frac.', 'Cu - K bond frac.', 'Cu - La bond frac.', 'Cu - Li bond frac.', 'Cu - Lu bond frac.', 'Cu - Mg bond frac.', 'Cu - Mn bond frac.', 'Cu - Mo bond frac.', 'Cu - N bond frac.', 'Cu - Na bond frac.', 'Cu - Nb bond frac.', 'Cu - Nd bond frac.', 'Cu - Ni bond frac.', 'Cu - Np bond frac.', 'Cu - O bond frac.', 'Cu - Os bond frac.', 'Cu - P bond frac.', 'Cu - Pa bond frac.', 'Cu - Pb bond frac.', 'Cu - Pd bond frac.', 'Cu - Pm bond frac.', 'Cu - Pr bond frac.', 'Cu - Pt bond frac.', 'Cu - Pu bond frac.', 'Cu - Rb bond frac.', 'Cu - Re bond frac.', 'Cu - Rh bond frac.', 'Cu - Ru bond frac.', 'Cu - S bond frac.', 'Cu - Sb bond frac.', 'Cu - Sc bond frac.', 'Cu - Se bond frac.', 'Cu - Si bond frac.', 'Cu - Sm bond frac.', 'Cu - Sn bond frac.', 'Cu - Sr bond frac.', 'Cu - Ta bond frac.', 'Cu - Tb bond frac.', 'Cu - Tc bond frac.', 'Cu - Te bond frac.', 'Cu - Th bond frac.', 'Cu - Ti bond frac.', 'Cu - Tl bond frac.', 'Cu - Tm bond frac.', 'Cu - U bond frac.', 'Cu - V bond frac.', 'Cu - W bond frac.', 'Cu - Xe bond frac.', 'Cu - Y bond frac.', 'Cu - Yb bond frac.', 'Cu - Zn bond frac.', 'Cu - Zr bond frac.', 'Dy - Dy bond frac.', 'Dy - Er bond frac.', 'Dy - Eu bond frac.', 'Dy - F bond frac.', 'Dy - Fe bond frac.', 'Dy - Ga bond frac.', 'Dy - Gd bond frac.', 'Dy - Ge bond frac.', 'Dy - H bond frac.', 'Dy - Hf bond frac.', 'Dy - Hg bond frac.', 'Dy - Ho bond frac.', 'Dy - I bond frac.', 'Dy - In bond frac.', 'Dy - Ir bond frac.', 'Dy - K bond frac.', 'Dy - La bond frac.', 'Dy - Li bond frac.', 'Dy - Lu bond frac.', 'Dy - Mg bond frac.', 'Dy - Mn bond frac.', 'Dy - Mo bond frac.', 'Dy - N bond frac.', 'Dy - Na bond frac.', 'Dy - Nb bond frac.', 'Dy - Nd bond frac.', 'Dy - Ni bond frac.', 'Dy - Np bond frac.', 'Dy - O bond frac.', 'Dy - Os bond frac.', 'Dy - P bond frac.', 'Dy - Pa bond frac.', 'Dy - Pb bond frac.', 'Dy - Pd bond frac.', 'Dy - Pm bond frac.', 'Dy - Pr bond frac.', 'Dy - Pt bond frac.', 'Dy - Pu bond frac.', 'Dy - Rb bond frac.', 'Dy - Re bond frac.', 'Dy - Rh bond frac.', 'Dy - Ru bond frac.', 'Dy - S bond frac.', 'Dy - Sb bond frac.', 'Dy - Sc bond frac.', 'Dy - Se bond frac.', 'Dy - Si bond frac.', 'Dy - Sm bond frac.', 'Dy - Sn bond frac.', 'Dy - Sr bond frac.', 'Dy - Ta bond frac.', 'Dy - Tb bond frac.', 'Dy - Tc bond frac.', 'Dy - Te bond frac.', 'Dy - Th bond frac.', 'Dy - Ti bond frac.', 'Dy - Tl bond frac.', 'Dy - Tm bond frac.', 'Dy - U bond frac.', 'Dy - V bond frac.', 'Dy - W bond frac.', 'Dy - Y bond frac.', 'Dy - Yb bond frac.', 'Dy - Zn bond frac.', 'Dy - Zr bond frac.', 'Er - Er bond frac.', 'Er - Eu bond frac.', 'Er - F bond frac.', 'Er - Fe bond frac.', 'Er - Ga bond frac.', 'Er - Gd bond frac.', 'Er - Ge bond frac.', 'Er - H bond frac.', 'Er - Hf bond frac.', 'Er - Hg bond frac.', 'Er - Ho bond frac.', 'Er - I bond frac.', 'Er - In bond frac.', 'Er - Ir bond frac.', 'Er - K bond frac.', 'Er - La bond frac.', 'Er - Li bond frac.', 'Er - Lu bond frac.', 'Er - Mg bond frac.', 'Er - Mn bond frac.', 'Er - Mo bond frac.', 'Er - N bond frac.', 'Er - Na bond frac.', 'Er - Nb bond frac.', 'Er - Nd bond frac.', 'Er - Ni bond frac.', 'Er - Np bond frac.', 'Er - O bond frac.', 'Er - Os bond frac.', 'Er - P bond frac.', 'Er - Pa bond frac.', 'Er - Pb bond frac.', 'Er - Pd bond frac.', 'Er - Pm bond frac.', 'Er - Pr bond frac.', 'Er - Pt bond frac.', 'Er - Pu bond frac.', 'Er - Rb bond frac.', 'Er - Re bond frac.', 'Er - Rh bond frac.', 'Er - Ru bond frac.', 'Er - S bond frac.', 'Er - Sb bond frac.', 'Er - Sc bond frac.', 'Er - Se bond frac.', 'Er - Si bond frac.', 'Er - Sm bond frac.', 'Er - Sn bond frac.', 'Er - Sr bond frac.', 'Er - Ta bond frac.', 'Er - Tb bond frac.', 'Er - Tc bond frac.', 'Er - Te bond frac.', 'Er - Th bond frac.', 'Er - Ti bond frac.', 'Er - Tl bond frac.', 'Er - Tm bond frac.', 'Er - U bond frac.', 'Er - V bond frac.', 'Er - W bond frac.', 'Er - Y bond frac.', 'Er - Yb bond frac.', 'Er - Zn bond frac.', 'Er - Zr bond frac.', 'Eu - Eu bond frac.', 'Eu - F bond frac.', 'Eu - Fe bond frac.', 'Eu - Ga bond frac.', 'Eu - Gd bond frac.', 'Eu - Ge bond frac.', 'Eu - H bond frac.', 'Eu - Hf bond frac.', 'Eu - Hg bond frac.', 'Eu - Ho bond frac.', 'Eu - I bond frac.', 'Eu - In bond frac.', 'Eu - Ir bond frac.', 'Eu - K bond frac.', 'Eu - La bond frac.', 'Eu - Li bond frac.', 'Eu - Lu bond frac.', 'Eu - Mg bond frac.', 'Eu - Mn bond frac.', 'Eu - Mo bond frac.', 'Eu - N bond frac.', 'Eu - Na bond frac.', 'Eu - Nb bond frac.', 'Eu - Nd bond frac.', 'Eu - Ni bond frac.', 'Eu - Np bond frac.', 'Eu - O bond frac.', 'Eu - Os bond frac.', 'Eu - P bond frac.', 'Eu - Pa bond frac.', 'Eu - Pb bond frac.', 'Eu - Pd bond frac.', 'Eu - Pm bond frac.', 'Eu - Pr bond frac.', 'Eu - Pt bond frac.', 'Eu - Pu bond frac.', 'Eu - Rb bond frac.', 'Eu - Re bond frac.', 'Eu - Rh bond frac.', 'Eu - Ru bond frac.', 'Eu - S bond frac.', 'Eu - Sb bond frac.', 'Eu - Sc bond frac.', 'Eu - Se bond frac.', 'Eu - Si bond frac.', 'Eu - Sm bond frac.', 'Eu - Sn bond frac.', 'Eu - Sr bond frac.', 'Eu - Ta bond frac.', 'Eu - Tb bond frac.', 'Eu - Tc bond frac.', 'Eu - Te bond frac.', 'Eu - Th bond frac.', 'Eu - Ti bond frac.', 'Eu - Tl bond frac.', 'Eu - Tm bond frac.', 'Eu - U bond frac.', 'Eu - V bond frac.', 'Eu - W bond frac.', 'Eu - Y bond frac.', 'Eu - Yb bond frac.', 'Eu - Zn bond frac.', 'Eu - Zr bond frac.', 'F - F bond frac.', 'F - Fe bond frac.', 'F - Ga bond frac.', 'F - Gd bond frac.', 'F - Ge bond frac.', 'F - H bond frac.', 'F - Hf bond frac.', 'F - Hg bond frac.', 'F - Ho bond frac.', 'F - I bond frac.', 'F - In bond frac.', 'F - Ir bond frac.', 'F - K bond frac.', 'F - Kr bond frac.', 'F - La bond frac.', 'F - Li bond frac.', 'F - Lu bond frac.', 'F - Mg bond frac.', 'F - Mn bond frac.', 'F - Mo bond frac.', 'F - N bond frac.', 'F - Na bond frac.', 'F - Nb bond frac.', 'F - Nd bond frac.', 'F - Ni bond frac.', 'F - Np bond frac.', 'F - O bond frac.', 'F - Os bond frac.', 'F - P bond frac.', 'F - Pa bond frac.', 'F - Pb bond frac.', 'F - Pd bond frac.', 'F - Pm bond frac.', 'F - Pr bond frac.', 'F - Pt bond frac.', 'F - Pu bond frac.', 'F - Rb bond frac.', 'F - Re bond frac.', 'F - Rh bond frac.', 'F - Ru bond frac.', 'F - S bond frac.', 'F - Sb bond frac.', 'F - Sc bond frac.', 'F - Se bond frac.', 'F - Si bond frac.', 'F - Sm bond frac.', 'F - Sn bond frac.', 'F - Sr bond frac.', 'F - Ta bond frac.', 'F - Tb bond frac.', 'F - Tc bond frac.', 'F - Te bond frac.', 'F - Th bond frac.', 'F - Ti bond frac.', 'F - Tl bond frac.', 'F - Tm bond frac.', 'F - U bond frac.', 'F - V bond frac.', 'F - W bond frac.', 'F - Xe bond frac.', 'F - Y bond frac.', 'F - Yb bond frac.', 'F - Zn bond frac.', 'F - Zr bond frac.', 'Fe - Fe bond frac.', 'Fe - Ga bond frac.', 'Fe - Gd bond frac.', 'Fe - Ge bond frac.', 'Fe - H bond frac.', 'Fe - Hf bond frac.', 'Fe - Hg bond frac.', 'Fe - Ho bond frac.', 'Fe - I bond frac.', 'Fe - In bond frac.', 'Fe - Ir bond frac.', 'Fe - K bond frac.', 'Fe - La bond frac.', 'Fe - Li bond frac.', 'Fe - Lu bond frac.', 'Fe - Mg bond frac.', 'Fe - Mn bond frac.', 'Fe - Mo bond frac.', 'Fe - N bond frac.', 'Fe - Na bond frac.', 'Fe - Nb bond frac.', 'Fe - Nd bond frac.', 'Fe - Ni bond frac.', 'Fe - Np bond frac.', 'Fe - O bond frac.', 'Fe - Os bond frac.', 'Fe - P bond frac.', 'Fe - Pa bond frac.', 'Fe - Pb bond frac.', 'Fe - Pd bond frac.', 'Fe - Pr bond frac.', 'Fe - Pt bond frac.', 'Fe - Pu bond frac.', 'Fe - Rb bond frac.', 'Fe - Re bond frac.', 'Fe - Rh bond frac.', 'Fe - Ru bond frac.', 'Fe - S bond frac.', 'Fe - Sb bond frac.', 'Fe - Sc bond frac.', 'Fe - Se bond frac.', 'Fe - Si bond frac.', 'Fe - Sm bond frac.', 'Fe - Sn bond frac.', 'Fe - Sr bond frac.', 'Fe - Ta bond frac.', 'Fe - Tb bond frac.', 'Fe - Tc bond frac.', 'Fe - Te bond frac.', 'Fe - Th bond frac.', 'Fe - Ti bond frac.', 'Fe - Tl bond frac.', 'Fe - Tm bond frac.', 'Fe - U bond frac.', 'Fe - V bond frac.', 'Fe - W bond frac.', 'Fe - Xe bond frac.', 'Fe - Y bond frac.', 'Fe - Yb bond frac.', 'Fe - Zn bond frac.', 'Fe - Zr bond frac.', 'Ga - Ga bond frac.', 'Ga - Gd bond frac.', 'Ga - Ge bond frac.', 'Ga - H bond frac.', 'Ga - Hf bond frac.', 'Ga - Hg bond frac.', 'Ga - Ho bond frac.', 'Ga - I bond frac.', 'Ga - In bond frac.', 'Ga - Ir bond frac.', 'Ga - K bond frac.', 'Ga - La bond frac.', 'Ga - Li bond frac.', 'Ga - Lu bond frac.', 'Ga - Mg bond frac.', 'Ga - Mn bond frac.', 'Ga - Mo bond frac.', 'Ga - N bond frac.', 'Ga - Na bond frac.', 'Ga - Nb bond frac.', 'Ga - Nd bond frac.', 'Ga - Ni bond frac.', 'Ga - Np bond frac.', 'Ga - O bond frac.', 'Ga - Os bond frac.', 'Ga - P bond frac.', 'Ga - Pa bond frac.', 'Ga - Pb bond frac.', 'Ga - Pd bond frac.', 'Ga - Pm bond frac.', 'Ga - Pr bond frac.', 'Ga - Pt bond frac.', 'Ga - Pu bond frac.', 'Ga - Rb bond frac.', 'Ga - Re bond frac.', 'Ga - Rh bond frac.', 'Ga - Ru bond frac.', 'Ga - S bond frac.', 'Ga - Sb bond frac.', 'Ga - Sc bond frac.', 'Ga - Se bond frac.', 'Ga - Si bond frac.', 'Ga - Sm bond frac.', 'Ga - Sn bond frac.', 'Ga - Sr bond frac.', 'Ga - Ta bond frac.', 'Ga - Tb bond frac.', 'Ga - Tc bond frac.', 'Ga - Te bond frac.', 'Ga - Th bond frac.', 'Ga - Ti bond frac.', 'Ga - Tl bond frac.', 'Ga - Tm bond frac.', 'Ga - U bond frac.', 'Ga - V bond frac.', 'Ga - W bond frac.', 'Ga - Y bond frac.', 'Ga - Yb bond frac.', 'Ga - Zn bond frac.', 'Ga - Zr bond frac.', 'Gd - Gd bond frac.', 'Gd - Ge bond frac.', 'Gd - H bond frac.', 'Gd - Hf bond frac.', 'Gd - Hg bond frac.', 'Gd - Ho bond frac.', 'Gd - I bond frac.', 'Gd - In bond frac.', 'Gd - Ir bond frac.', 'Gd - K bond frac.', 'Gd - La bond frac.', 'Gd - Li bond frac.', 'Gd - Lu bond frac.', 'Gd - Mg bond frac.', 'Gd - Mn bond frac.', 'Gd - Mo bond frac.', 'Gd - N bond frac.', 'Gd - Na bond frac.', 'Gd - Nb bond frac.', 'Gd - Nd bond frac.', 'Gd - Ni bond frac.', 'Gd - Np bond frac.', 'Gd - O bond frac.', 'Gd - Os bond frac.', 'Gd - P bond frac.', 'Gd - Pa bond frac.', 'Gd - Pb bond frac.', 'Gd - Pd bond frac.', 'Gd - Pm bond frac.', 'Gd - Pr bond frac.', 'Gd - Pt bond frac.', 'Gd - Rb bond frac.', 'Gd - Re bond frac.', 'Gd - Rh bond frac.', 'Gd - Ru bond frac.', 'Gd - S bond frac.', 'Gd - Sb bond frac.', 'Gd - Sc bond frac.', 'Gd - Se bond frac.', 'Gd - Si bond frac.', 'Gd - Sm bond frac.', 'Gd - Sn bond frac.', 'Gd - Sr bond frac.', 'Gd - Ta bond frac.', 'Gd - Tb bond frac.', 'Gd - Tc bond frac.', 'Gd - Te bond frac.', 'Gd - Th bond frac.', 'Gd - Ti bond frac.', 'Gd - Tl bond frac.', 'Gd - Tm bond frac.', 'Gd - U bond frac.', 'Gd - V bond frac.', 'Gd - W bond frac.', 'Gd - Y bond frac.', 'Gd - Yb bond frac.', 'Gd - Zn bond frac.', 'Gd - Zr bond frac.', 'Ge - Ge bond frac.', 'Ge - H bond frac.', 'Ge - Hf bond frac.', 'Ge - Hg bond frac.', 'Ge - Ho bond frac.', 'Ge - I bond frac.', 'Ge - In bond frac.', 'Ge - Ir bond frac.', 'Ge - K bond frac.', 'Ge - La bond frac.', 'Ge - Li bond frac.', 'Ge - Lu bond frac.', 'Ge - Mg bond frac.', 'Ge - Mn bond frac.', 'Ge - Mo bond frac.', 'Ge - N bond frac.', 'Ge - Na bond frac.', 'Ge - Nb bond frac.', 'Ge - Nd bond frac.', 'Ge - Ni bond frac.', 'Ge - Np bond frac.', 'Ge - O bond frac.', 'Ge - Os bond frac.', 'Ge - P bond frac.', 'Ge - Pa bond frac.', 'Ge - Pb bond frac.', 'Ge - Pd bond frac.', 'Ge - Pm bond frac.', 'Ge - Pr bond frac.', 'Ge - Pt bond frac.', 'Ge - Pu bond frac.', 'Ge - Rb bond frac.', 'Ge - Re bond frac.', 'Ge - Rh bond frac.', 'Ge - Ru bond frac.', 'Ge - S bond frac.', 'Ge - Sb bond frac.', 'Ge - Sc bond frac.', 'Ge - Se bond frac.', 'Ge - Si bond frac.', 'Ge - Sm bond frac.', 'Ge - Sn bond frac.', 'Ge - Sr bond frac.', 'Ge - Ta bond frac.', 'Ge - Tb bond frac.', 'Ge - Tc bond frac.', 'Ge - Te bond frac.', 'Ge - Th bond frac.', 'Ge - Ti bond frac.', 'Ge - Tl bond frac.', 'Ge - Tm bond frac.', 'Ge - U bond frac.', 'Ge - V bond frac.', 'Ge - W bond frac.', 'Ge - Xe bond frac.', 'Ge - Y bond frac.', 'Ge - Yb bond frac.', 'Ge - Zn bond frac.', 'Ge - Zr bond frac.', 'H - H bond frac.', 'H - Hf bond frac.', 'H - Hg bond frac.', 'H - Ho bond frac.', 'H - I bond frac.', 'H - In bond frac.', 'H - Ir bond frac.', 'H - K bond frac.', 'H - La bond frac.', 'H - Li bond frac.', 'H - Lu bond frac.', 'H - Mg bond frac.', 'H - Mn bond frac.', 'H - Mo bond frac.', 'H - N bond frac.', 'H - Na bond frac.', 'H - Nb bond frac.', 'H - Nd bond frac.', 'H - Ni bond frac.', 'H - Np bond frac.', 'H - O bond frac.', 'H - Os bond frac.', 'H - P bond frac.', 'H - Pa bond frac.', 'H - Pb bond frac.', 'H - Pd bond frac.', 'H - Pm bond frac.', 'H - Pr bond frac.', 'H - Pt bond frac.', 'H - Pu bond frac.', 'H - Rb bond frac.', 'H - Re bond frac.', 'H - Rh bond frac.', 'H - Ru bond frac.', 'H - S bond frac.', 'H - Sb bond frac.', 'H - Sc bond frac.', 'H - Se bond frac.', 'H - Si bond frac.', 'H - Sm bond frac.', 'H - Sn bond frac.', 'H - Sr bond frac.', 'H - Ta bond frac.', 'H - Tb bond frac.', 'H - Tc bond frac.', 'H - Te bond frac.', 'H - Th bond frac.', 'H - Ti bond frac.', 'H - Tl bond frac.', 'H - Tm bond frac.', 'H - U bond frac.', 'H - V bond frac.', 'H - W bond frac.', 'H - Xe bond frac.', 'H - Y bond frac.', 'H - Yb bond frac.', 'H - Zn bond frac.', 'H - Zr bond frac.', 'He - He bond frac.', 'He - O bond frac.', 'He - Si bond frac.', 'Hf - Hf bond frac.', 'Hf - Hg bond frac.', 'Hf - Ho bond frac.', 'Hf - I bond frac.', 'Hf - In bond frac.', 'Hf - Ir bond frac.', 'Hf - K bond frac.', 'Hf - La bond frac.', 'Hf - Li bond frac.', 'Hf - Lu bond frac.', 'Hf - Mg bond frac.', 'Hf - Mn bond frac.', 'Hf - Mo bond frac.', 'Hf - N bond frac.', 'Hf - Na bond frac.', 'Hf - Nb bond frac.', 'Hf - Nd bond frac.', 'Hf - Ni bond frac.', 'Hf - Np bond frac.', 'Hf - O bond frac.', 'Hf - Os bond frac.', 'Hf - P bond frac.', 'Hf - Pa bond frac.', 'Hf - Pb bond frac.', 'Hf - Pd bond frac.', 'Hf - Pm bond frac.', 'Hf - Pr bond frac.', 'Hf - Pt bond frac.', 'Hf - Pu bond frac.', 'Hf - Rb bond frac.', 'Hf - Re bond frac.', 'Hf - Rh bond frac.', 'Hf - Ru bond frac.', 'Hf - S bond frac.', 'Hf - Sb bond frac.', 'Hf - Sc bond frac.', 'Hf - Se bond frac.', 'Hf - Si bond frac.', 'Hf - Sm bond frac.', 'Hf - Sn bond frac.', 'Hf - Sr bond frac.', 'Hf - Ta bond frac.', 'Hf - Tb bond frac.', 'Hf - Tc bond frac.', 'Hf - Te bond frac.', 'Hf - Th bond frac.', 'Hf - Ti bond frac.', 'Hf - Tl bond frac.', 'Hf - Tm bond frac.', 'Hf - U bond frac.', 'Hf - V bond frac.', 'Hf - W bond frac.', 'Hf - Y bond frac.', 'Hf - Yb bond frac.', 'Hf - Zn bond frac.', 'Hf - Zr bond frac.', 'Hg - Hg bond frac.', 'Hg - Ho bond frac.', 'Hg - I bond frac.', 'Hg - In bond frac.', 'Hg - Ir bond frac.', 'Hg - K bond frac.', 'Hg - Kr bond frac.', 'Hg - La bond frac.', 'Hg - Li bond frac.', 'Hg - Lu bond frac.', 'Hg - Mg bond frac.', 'Hg - Mn bond frac.', 'Hg - Mo bond frac.', 'Hg - N bond frac.', 'Hg - Na bond frac.', 'Hg - Nb bond frac.', 'Hg - Nd bond frac.', 'Hg - Ni bond frac.', 'Hg - Np bond frac.', 'Hg - O bond frac.', 'Hg - Os bond frac.', 'Hg - P bond frac.', 'Hg - Pa bond frac.', 'Hg - Pb bond frac.', 'Hg - Pd bond frac.', 'Hg - Pm bond frac.', 'Hg - Pr bond frac.', 'Hg - Pt bond frac.', 'Hg - Pu bond frac.', 'Hg - Rb bond frac.', 'Hg - Re bond frac.', 'Hg - Rh bond frac.', 'Hg - Ru bond frac.', 'Hg - S bond frac.', 'Hg - Sb bond frac.', 'Hg - Sc bond frac.', 'Hg - Se bond frac.', 'Hg - Si bond frac.', 'Hg - Sm bond frac.', 'Hg - Sn bond frac.', 'Hg - Sr bond frac.', 'Hg - Ta bond frac.', 'Hg - Tb bond frac.', 'Hg - Tc bond frac.', 'Hg - Te bond frac.', 'Hg - Th bond frac.', 'Hg - Ti bond frac.', 'Hg - Tl bond frac.', 'Hg - Tm bond frac.', 'Hg - U bond frac.', 'Hg - V bond frac.', 'Hg - W bond frac.', 'Hg - Xe bond frac.', 'Hg - Y bond frac.', 'Hg - Yb bond frac.', 'Hg - Zn bond frac.', 'Hg - Zr bond frac.', 'Ho - Ho bond frac.', 'Ho - I bond frac.', 'Ho - In bond frac.', 'Ho - Ir bond frac.', 'Ho - K bond frac.', 'Ho - La bond frac.', 'Ho - Li bond frac.', 'Ho - Lu bond frac.', 'Ho - Mg bond frac.', 'Ho - Mn bond frac.', 'Ho - Mo bond frac.', 'Ho - N bond frac.', 'Ho - Na bond frac.', 'Ho - Nb bond frac.', 'Ho - Nd bond frac.', 'Ho - Ni bond frac.', 'Ho - Np bond frac.', 'Ho - O bond frac.', 'Ho - Os bond frac.', 'Ho - P bond frac.', 'Ho - Pa bond frac.', 'Ho - Pb bond frac.', 'Ho - Pd bond frac.', 'Ho - Pm bond frac.', 'Ho - Pr bond frac.', 'Ho - Pt bond frac.', 'Ho - Pu bond frac.', 'Ho - Rb bond frac.', 'Ho - Re bond frac.', 'Ho - Rh bond frac.', 'Ho - Ru bond frac.', 'Ho - S bond frac.', 'Ho - Sb bond frac.', 'Ho - Sc bond frac.', 'Ho - Se bond frac.', 'Ho - Si bond frac.', 'Ho - Sm bond frac.', 'Ho - Sn bond frac.', 'Ho - Sr bond frac.', 'Ho - Ta bond frac.', 'Ho - Tb bond frac.', 'Ho - Tc bond frac.', 'Ho - Te bond frac.', 'Ho - Th bond frac.', 'Ho - Ti bond frac.', 'Ho - Tl bond frac.', 'Ho - Tm bond frac.', 'Ho - U bond frac.', 'Ho - V bond frac.', 'Ho - W bond frac.', 'Ho - Y bond frac.', 'Ho - Yb bond frac.', 'Ho - Zn bond frac.', 'Ho - Zr bond frac.', 'I - I bond frac.', 'I - In bond frac.', 'I - Ir bond frac.', 'I - K bond frac.', 'I - La bond frac.', 'I - Li bond frac.', 'I - Lu bond frac.', 'I - Mg bond frac.', 'I - Mn bond frac.', 'I - Mo bond frac.', 'I - N bond frac.', 'I - Na bond frac.', 'I - Nb bond frac.', 'I - Nd bond frac.', 'I - Ni bond frac.', 'I - Np bond frac.', 'I - O bond frac.', 'I - Os bond frac.', 'I - P bond frac.', 'I - Pa bond frac.', 'I - Pb bond frac.', 'I - Pd bond frac.', 'I - Pm bond frac.', 'I - Pr bond frac.', 'I - Pt bond frac.', 'I - Pu bond frac.', 'I - Rb bond frac.', 'I - Re bond frac.', 'I - Rh bond frac.', 'I - Ru bond frac.', 'I - S bond frac.', 'I - Sb bond frac.', 'I - Sc bond frac.', 'I - Se bond frac.', 'I - Si bond frac.', 'I - Sm bond frac.', 'I - Sn bond frac.', 'I - Sr bond frac.', 'I - Ta bond frac.', 'I - Tb bond frac.', 'I - Tc bond frac.', 'I - Te bond frac.', 'I - Th bond frac.', 'I - Ti bond frac.', 'I - Tl bond frac.', 'I - Tm bond frac.', 'I - U bond frac.', 'I - V bond frac.', 'I - W bond frac.', 'I - Xe bond frac.', 'I - Y bond frac.', 'I - Yb bond frac.', 'I - Zn bond frac.', 'I - Zr bond frac.', 'In - In bond frac.', 'In - Ir bond frac.', 'In - K bond frac.', 'In - La bond frac.', 'In - Li bond frac.', 'In - Lu bond frac.', 'In - Mg bond frac.', 'In - Mn bond frac.', 'In - Mo bond frac.', 'In - N bond frac.', 'In - Na bond frac.', 'In - Nb bond frac.', 'In - Nd bond frac.', 'In - Ni bond frac.', 'In - Np bond frac.', 'In - O bond frac.', 'In - Os bond frac.', 'In - P bond frac.', 'In - Pa bond frac.', 'In - Pb bond frac.', 'In - Pd bond frac.', 'In - Pm bond frac.', 'In - Pr bond frac.', 'In - Pt bond frac.', 'In - Pu bond frac.', 'In - Rb bond frac.', 'In - Re bond frac.', 'In - Rh bond frac.', 'In - Ru bond frac.', 'In - S bond frac.', 'In - Sb bond frac.', 'In - Sc bond frac.', 'In - Se bond frac.', 'In - Si bond frac.', 'In - Sm bond frac.', 'In - Sn bond frac.', 'In - Sr bond frac.', 'In - Ta bond frac.', 'In - Tb bond frac.', 'In - Tc bond frac.', 'In - Te bond frac.', 'In - Th bond frac.', 'In - Ti bond frac.', 'In - Tl bond frac.', 'In - Tm bond frac.', 'In - U bond frac.', 'In - V bond frac.', 'In - W bond frac.', 'In - Y bond frac.', 'In - Yb bond frac.', 'In - Zn bond frac.', 'In - Zr bond frac.', 'Ir - Ir bond frac.', 'Ir - K bond frac.', 'Ir - La bond frac.', 'Ir - Li bond frac.', 'Ir - Lu bond frac.', 'Ir - Mg bond frac.', 'Ir - Mn bond frac.', 'Ir - Mo bond frac.', 'Ir - N bond frac.', 'Ir - Na bond frac.', 'Ir - Nb bond frac.', 'Ir - Nd bond frac.', 'Ir - Ni bond frac.', 'Ir - Np bond frac.', 'Ir - O bond frac.', 'Ir - Os bond frac.', 'Ir - P bond frac.', 'Ir - Pa bond frac.', 'Ir - Pb bond frac.', 'Ir - Pd bond frac.', 'Ir - Pm bond frac.', 'Ir - Pr bond frac.', 'Ir - Pt bond frac.', 'Ir - Pu bond frac.', 'Ir - Rb bond frac.', 'Ir - Re bond frac.', 'Ir - Rh bond frac.', 'Ir - Ru bond frac.', 'Ir - S bond frac.', 'Ir - Sb bond frac.', 'Ir - Sc bond frac.', 'Ir - Se bond frac.', 'Ir - Si bond frac.', 'Ir - Sm bond frac.', 'Ir - Sn bond frac.', 'Ir - Sr bond frac.', 'Ir - Ta bond frac.', 'Ir - Tb bond frac.', 'Ir - Tc bond frac.', 'Ir - Te bond frac.', 'Ir - Th bond frac.', 'Ir - Ti bond frac.', 'Ir - Tl bond frac.', 'Ir - Tm bond frac.', 'Ir - U bond frac.', 'Ir - V bond frac.', 'Ir - W bond frac.', 'Ir - Xe bond frac.', 'Ir - Y bond frac.', 'Ir - Yb bond frac.', 'Ir - Zn bond frac.', 'Ir - Zr bond frac.', 'K - K bond frac.', 'K - La bond frac.', 'K - Li bond frac.', 'K - Lu bond frac.', 'K - Mg bond frac.', 'K - Mn bond frac.', 'K - Mo bond frac.', 'K - N bond frac.', 'K - Na bond frac.', 'K - Nb bond frac.', 'K - Nd bond frac.', 'K - Ni bond frac.', 'K - Np bond frac.', 'K - O bond frac.', 'K - Os bond frac.', 'K - P bond frac.', 'K - Pa bond frac.', 'K - Pb bond frac.', 'K - Pd bond frac.', 'K - Pm bond frac.', 'K - Pr bond frac.', 'K - Pt bond frac.', 'K - Pu bond frac.', 'K - Rb bond frac.', 'K - Re bond frac.', 'K - Rh bond frac.', 'K - Ru bond frac.', 'K - S bond frac.', 'K - Sb bond frac.', 'K - Sc bond frac.', 'K - Se bond frac.', 'K - Si bond frac.', 'K - Sm bond frac.', 'K - Sn bond frac.', 'K - Sr bond frac.', 'K - Ta bond frac.', 'K - Tb bond frac.', 'K - Tc bond frac.', 'K - Te bond frac.', 'K - Th bond frac.', 'K - Ti bond frac.', 'K - Tl bond frac.', 'K - Tm bond frac.', 'K - U bond frac.', 'K - V bond frac.', 'K - W bond frac.', 'K - Xe bond frac.', 'K - Y bond frac.', 'K - Yb bond frac.', 'K - Zn bond frac.', 'K - Zr bond frac.', 'Kr - Kr bond frac.', 'Kr - O bond frac.', 'Kr - Sb bond frac.', 'Kr - Te bond frac.', 'La - La bond frac.', 'La - Li bond frac.', 'La - Lu bond frac.', 'La - Mg bond frac.', 'La - Mn bond frac.', 'La - Mo bond frac.', 'La - N bond frac.', 'La - Na bond frac.', 'La - Nb bond frac.', 'La - Nd bond frac.', 'La - Ni bond frac.', 'La - Np bond frac.', 'La - O bond frac.', 'La - Os bond frac.', 'La - P bond frac.', 'La - Pa bond frac.', 'La - Pb bond frac.', 'La - Pd bond frac.', 'La - Pm bond frac.', 'La - Pr bond frac.', 'La - Pt bond frac.', 'La - Pu bond frac.', 'La - Rb bond frac.', 'La - Re bond frac.', 'La - Rh bond frac.', 'La - Ru bond frac.', 'La - S bond frac.', 'La - Sb bond frac.', 'La - Sc bond frac.', 'La - Se bond frac.', 'La - Si bond frac.', 'La - Sm bond frac.', 'La - Sn bond frac.', 'La - Sr bond frac.', 'La - Ta bond frac.', 'La - Tb bond frac.', 'La - Tc bond frac.', 'La - Te bond frac.', 'La - Th bond frac.', 'La - Ti bond frac.', 'La - Tl bond frac.', 'La - Tm bond frac.', 'La - U bond frac.', 'La - V bond frac.', 'La - W bond frac.', 'La - Y bond frac.', 'La - Yb bond frac.', 'La - Zn bond frac.', 'La - Zr bond frac.', 'Li - Li bond frac.', 'Li - Lu bond frac.', 'Li - Mg bond frac.', 'Li - Mn bond frac.', 'Li - Mo bond frac.', 'Li - N bond frac.', 'Li - Na bond frac.', 'Li - Nb bond frac.', 'Li - Nd bond frac.', 'Li - Ni bond frac.', 'Li - Np bond frac.', 'Li - O bond frac.', 'Li - Os bond frac.', 'Li - P bond frac.', 'Li - Pa bond frac.', 'Li - Pb bond frac.', 'Li - Pd bond frac.', 'Li - Pm bond frac.', 'Li - Pr bond frac.', 'Li - Pt bond frac.', 'Li - Pu bond frac.', 'Li - Rb bond frac.', 'Li - Re bond frac.', 'Li - Rh bond frac.', 'Li - Ru bond frac.', 'Li - S bond frac.', 'Li - Sb bond frac.', 'Li - Sc bond frac.', 'Li - Se bond frac.', 'Li - Si bond frac.', 'Li - Sm bond frac.', 'Li - Sn bond frac.', 'Li - Sr bond frac.', 'Li - Ta bond frac.', 'Li - Tb bond frac.', 'Li - Tc bond frac.', 'Li - Te bond frac.', 'Li - Th bond frac.', 'Li - Ti bond frac.', 'Li - Tl bond frac.', 'Li - Tm bond frac.', 'Li - U bond frac.', 'Li - V bond frac.', 'Li - W bond frac.', 'Li - Xe bond frac.', 'Li - Y bond frac.', 'Li - Yb bond frac.', 'Li - Zn bond frac.', 'Li - Zr bond frac.', 'Lu - Lu bond frac.', 'Lu - Mg bond frac.', 'Lu - Mn bond frac.', 'Lu - Mo bond frac.', 'Lu - N bond frac.', 'Lu - Na bond frac.', 'Lu - Nb bond frac.', 'Lu - Nd bond frac.', 'Lu - Ni bond frac.', 'Lu - Np bond frac.', 'Lu - O bond frac.', 'Lu - Os bond frac.', 'Lu - P bond frac.', 'Lu - Pa bond frac.', 'Lu - Pb bond frac.', 'Lu - Pd bond frac.', 'Lu - Pm bond frac.', 'Lu - Pr bond frac.', 'Lu - Pt bond frac.', 'Lu - Pu bond frac.', 'Lu - Rb bond frac.', 'Lu - Re bond frac.', 'Lu - Rh bond frac.', 'Lu - Ru bond frac.', 'Lu - S bond frac.', 'Lu - Sb bond frac.', 'Lu - Sc bond frac.', 'Lu - Se bond frac.', 'Lu - Si bond frac.', 'Lu - Sm bond frac.', 'Lu - Sn bond frac.', 'Lu - Sr bond frac.', 'Lu - Ta bond frac.', 'Lu - Tb bond frac.', 'Lu - Tc bond frac.', 'Lu - Te bond frac.', 'Lu - Th bond frac.', 'Lu - Ti bond frac.', 'Lu - Tl bond frac.', 'Lu - Tm bond frac.', 'Lu - U bond frac.', 'Lu - V bond frac.', 'Lu - W bond frac.', 'Lu - Y bond frac.', 'Lu - Yb bond frac.', 'Lu - Zn bond frac.', 'Lu - Zr bond frac.', 'Mg - Mg bond frac.', 'Mg - Mn bond frac.', 'Mg - Mo bond frac.', 'Mg - N bond frac.', 'Mg - Na bond frac.', 'Mg - Nb bond frac.', 'Mg - Nd bond frac.', 'Mg - Ni bond frac.', 'Mg - Np bond frac.', 'Mg - O bond frac.', 'Mg - Os bond frac.', 'Mg - P bond frac.', 'Mg - Pa bond frac.', 'Mg - Pb bond frac.', 'Mg - Pd bond frac.', 'Mg - Pm bond frac.', 'Mg - Pr bond frac.', 'Mg - Pt bond frac.', 'Mg - Pu bond frac.', 'Mg - Rb bond frac.', 'Mg - Re bond frac.', 'Mg - Rh bond frac.', 'Mg - Ru bond frac.', 'Mg - S bond frac.', 'Mg - Sb bond frac.', 'Mg - Sc bond frac.', 'Mg - Se bond frac.', 'Mg - Si bond frac.', 'Mg - Sm bond frac.', 'Mg - Sn bond frac.', 'Mg - Sr bond frac.', 'Mg - Ta bond frac.', 'Mg - Tb bond frac.', 'Mg - Tc bond frac.', 'Mg - Te bond frac.', 'Mg - Th bond frac.', 'Mg - Ti bond frac.', 'Mg - Tl bond frac.', 'Mg - Tm bond frac.', 'Mg - U bond frac.', 'Mg - V bond frac.', 'Mg - W bond frac.', 'Mg - Xe bond frac.', 'Mg - Y bond frac.', 'Mg - Yb bond frac.', 'Mg - Zn bond frac.', 'Mg - Zr bond frac.', 'Mn - Mn bond frac.', 'Mn - Mo bond frac.', 'Mn - N bond frac.', 'Mn - Na bond frac.', 'Mn - Nb bond frac.', 'Mn - Nd bond frac.', 'Mn - Ni bond frac.', 'Mn - Np bond frac.', 'Mn - O bond frac.', 'Mn - Os bond frac.', 'Mn - P bond frac.', 'Mn - Pa bond frac.', 'Mn - Pb bond frac.', 'Mn - Pd bond frac.', 'Mn - Pm bond frac.', 'Mn - Pr bond frac.', 'Mn - Pt bond frac.', 'Mn - Pu bond frac.', 'Mn - Rb bond frac.', 'Mn - Re bond frac.', 'Mn - Rh bond frac.', 'Mn - Ru bond frac.', 'Mn - S bond frac.', 'Mn - Sb bond frac.', 'Mn - Sc bond frac.', 'Mn - Se bond frac.', 'Mn - Si bond frac.', 'Mn - Sm bond frac.', 'Mn - Sn bond frac.', 'Mn - Sr bond frac.', 'Mn - Ta bond frac.', 'Mn - Tb bond frac.', 'Mn - Tc bond frac.', 'Mn - Te bond frac.', 'Mn - Th bond frac.', 'Mn - Ti bond frac.', 'Mn - Tl bond frac.', 'Mn - Tm bond frac.', 'Mn - U bond frac.', 'Mn - V bond frac.', 'Mn - W bond frac.', 'Mn - Xe bond frac.', 'Mn - Y bond frac.', 'Mn - Yb bond frac.', 'Mn - Zn bond frac.', 'Mn - Zr bond frac.', 'Mo - Mo bond frac.', 'Mo - N bond frac.', 'Mo - Na bond frac.', 'Mo - Nb bond frac.', 'Mo - Nd bond frac.', 'Mo - Ni bond frac.', 'Mo - Np bond frac.', 'Mo - O bond frac.', 'Mo - Os bond frac.', 'Mo - P bond frac.', 'Mo - Pa bond frac.', 'Mo - Pb bond frac.', 'Mo - Pd bond frac.', 'Mo - Pr bond frac.', 'Mo - Pt bond frac.', 'Mo - Pu bond frac.', 'Mo - Rb bond frac.', 'Mo - Re bond frac.', 'Mo - Rh bond frac.', 'Mo - Ru bond frac.', 'Mo - S bond frac.', 'Mo - Sb bond frac.', 'Mo - Sc bond frac.', 'Mo - Se bond frac.', 'Mo - Si bond frac.', 'Mo - Sm bond frac.', 'Mo - Sn bond frac.', 'Mo - Sr bond frac.', 'Mo - Ta bond frac.', 'Mo - Tb bond frac.', 'Mo - Tc bond frac.', 'Mo - Te bond frac.', 'Mo - Th bond frac.', 'Mo - Ti bond frac.', 'Mo - Tl bond frac.', 'Mo - Tm bond frac.', 'Mo - U bond frac.', 'Mo - V bond frac.', 'Mo - W bond frac.', 'Mo - Y bond frac.', 'Mo - Yb bond frac.', 'Mo - Zn bond frac.', 'Mo - Zr bond frac.', 'N - N bond frac.', 'N - Na bond frac.', 'N - Nb bond frac.', 'N - Nd bond frac.', 'N - Ni bond frac.', 'N - Np bond frac.', 'N - O bond frac.', 'N - Os bond frac.', 'N - P bond frac.', 'N - Pa bond frac.', 'N - Pb bond frac.', 'N - Pd bond frac.', 'N - Pm bond frac.', 'N - Pr bond frac.', 'N - Pt bond frac.', 'N - Pu bond frac.', 'N - Rb bond frac.', 'N - Re bond frac.', 'N - Rh bond frac.', 'N - Ru bond frac.', 'N - S bond frac.', 'N - Sb bond frac.', 'N - Sc bond frac.', 'N - Se bond frac.', 'N - Si bond frac.', 'N - Sm bond frac.', 'N - Sn bond frac.', 'N - Sr bond frac.', 'N - Ta bond frac.', 'N - Tb bond frac.', 'N - Tc bond frac.', 'N - Te bond frac.', 'N - Th bond frac.', 'N - Ti bond frac.', 'N - Tl bond frac.', 'N - Tm bond frac.', 'N - U bond frac.', 'N - V bond frac.', 'N - W bond frac.', 'N - Xe bond frac.', 'N - Y bond frac.', 'N - Yb bond frac.', 'N - Zn bond frac.', 'N - Zr bond frac.', 'Na - Na bond frac.', 'Na - Nb bond frac.', 'Na - Nd bond frac.', 'Na - Ni bond frac.', 'Na - Np bond frac.', 'Na - O bond frac.', 'Na - Os bond frac.', 'Na - P bond frac.', 'Na - Pa bond frac.', 'Na - Pb bond frac.', 'Na - Pd bond frac.', 'Na - Pm bond frac.', 'Na - Pr bond frac.', 'Na - Pt bond frac.', 'Na - Pu bond frac.', 'Na - Rb bond frac.', 'Na - Re bond frac.', 'Na - Rh bond frac.', 'Na - Ru bond frac.', 'Na - S bond frac.', 'Na - Sb bond frac.', 'Na - Sc bond frac.', 'Na - Se bond frac.', 'Na - Si bond frac.', 'Na - Sm bond frac.', 'Na - Sn bond frac.', 'Na - Sr bond frac.', 'Na - Ta bond frac.', 'Na - Tb bond frac.', 'Na - Tc bond frac.', 'Na - Te bond frac.', 'Na - Th bond frac.', 'Na - Ti bond frac.', 'Na - Tl bond frac.', 'Na - Tm bond frac.', 'Na - U bond frac.', 'Na - V bond frac.', 'Na - W bond frac.', 'Na - Xe bond frac.', 'Na - Y bond frac.', 'Na - Yb bond frac.', 'Na - Zn bond frac.', 'Na - Zr bond frac.', 'Nb - Nb bond frac.', 'Nb - Nd bond frac.', 'Nb - Ni bond frac.', 'Nb - O bond frac.', 'Nb - Os bond frac.', 'Nb - P bond frac.', 'Nb - Pa bond frac.', 'Nb - Pb bond frac.', 'Nb - Pd bond frac.', 'Nb - Pr bond frac.', 'Nb - Pt bond frac.', 'Nb - Rb bond frac.', 'Nb - Re bond frac.', 'Nb - Rh bond frac.', 'Nb - Ru bond frac.', 'Nb - S bond frac.', 'Nb - Sb bond frac.', 'Nb - Sc bond frac.', 'Nb - Se bond frac.', 'Nb - Si bond frac.', 'Nb - Sm bond frac.', 'Nb - Sn bond frac.', 'Nb - Sr bond frac.', 'Nb - Ta bond frac.', 'Nb - Tb bond frac.', 'Nb - Tc bond frac.', 'Nb - Te bond frac.', 'Nb - Th bond frac.', 'Nb - Ti bond frac.', 'Nb - Tl bond frac.', 'Nb - Tm bond frac.', 'Nb - U bond frac.', 'Nb - V bond frac.', 'Nb - W bond frac.', 'Nb - Xe bond frac.', 'Nb - Y bond frac.', 'Nb - Yb bond frac.', 'Nb - Zn bond frac.', 'Nb - Zr bond frac.', 'Nd - Nd bond frac.', 'Nd - Ni bond frac.', 'Nd - Np bond frac.', 'Nd - O bond frac.', 'Nd - Os bond frac.', 'Nd - P bond frac.', 'Nd - Pa bond frac.', 'Nd - Pb bond frac.', 'Nd - Pd bond frac.', 'Nd - Pm bond frac.', 'Nd - Pr bond frac.', 'Nd - Pt bond frac.', 'Nd - Pu bond frac.', 'Nd - Rb bond frac.', 'Nd - Re bond frac.', 'Nd - Rh bond frac.', 'Nd - Ru bond frac.', 'Nd - S bond frac.', 'Nd - Sb bond frac.', 'Nd - Sc bond frac.', 'Nd - Se bond frac.', 'Nd - Si bond frac.', 'Nd - Sm bond frac.', 'Nd - Sn bond frac.', 'Nd - Sr bond frac.', 'Nd - Ta bond frac.', 'Nd - Tb bond frac.', 'Nd - Tc bond frac.', 'Nd - Te bond frac.', 'Nd - Th bond frac.', 'Nd - Ti bond frac.', 'Nd - Tl bond frac.', 'Nd - Tm bond frac.', 'Nd - U bond frac.', 'Nd - V bond frac.', 'Nd - W bond frac.', 'Nd - Xe bond frac.', 'Nd - Y bond frac.', 'Nd - Yb bond frac.', 'Nd - Zn bond frac.', 'Nd - Zr bond frac.', 'Ne - Ne bond frac.', 'Ni - Ni bond frac.', 'Ni - Np bond frac.', 'Ni - O bond frac.', 'Ni - Os bond frac.', 'Ni - P bond frac.', 'Ni - Pa bond frac.', 'Ni - Pb bond frac.', 'Ni - Pd bond frac.', 'Ni - Pm bond frac.', 'Ni - Pr bond frac.', 'Ni - Pt bond frac.', 'Ni - Pu bond frac.', 'Ni - Rb bond frac.', 'Ni - Re bond frac.', 'Ni - Rh bond frac.', 'Ni - Ru bond frac.', 'Ni - S bond frac.', 'Ni - Sb bond frac.', 'Ni - Sc bond frac.', 'Ni - Se bond frac.', 'Ni - Si bond frac.', 'Ni - Sm bond frac.', 'Ni - Sn bond frac.', 'Ni - Sr bond frac.', 'Ni - Ta bond frac.', 'Ni - Tb bond frac.', 'Ni - Tc bond frac.', 'Ni - Te bond frac.', 'Ni - Th bond frac.', 'Ni - Ti bond frac.', 'Ni - Tl bond frac.', 'Ni - Tm bond frac.', 'Ni - U bond frac.', 'Ni - V bond frac.', 'Ni - W bond frac.', 'Ni - Xe bond frac.', 'Ni - Y bond frac.', 'Ni - Yb bond frac.', 'Ni - Zn bond frac.', 'Ni - Zr bond frac.', 'Np - Np bond frac.', 'Np - O bond frac.', 'Np - Os bond frac.', 'Np - P bond frac.', 'Np - Pa bond frac.', 'Np - Pd bond frac.', 'Np - Pm bond frac.', 'Np - Pr bond frac.', 'Np - Pt bond frac.', 'Np - Pu bond frac.', 'Np - Rb bond frac.', 'Np - Re bond frac.', 'Np - Rh bond frac.', 'Np - Ru bond frac.', 'Np - S bond frac.', 'Np - Sb bond frac.', 'Np - Sc bond frac.', 'Np - Se bond frac.', 'Np - Si bond frac.', 'Np - Sm bond frac.', 'Np - Sn bond frac.', 'Np - Sr bond frac.', 'Np - Ta bond frac.', 'Np - Tb bond frac.', 'Np - Tc bond frac.', 'Np - Te bond frac.', 'Np - Th bond frac.', 'Np - Ti bond frac.', 'Np - Tl bond frac.', 'Np - Tm bond frac.', 'Np - U bond frac.', 'Np - V bond frac.', 'Np - W bond frac.', 'Np - Y bond frac.', 'Np - Zn bond frac.', 'Np - Zr bond frac.', 'O - O bond frac.', 'O - Os bond frac.', 'O - P bond frac.', 'O - Pa bond frac.', 'O - Pb bond frac.', 'O - Pd bond frac.', 'O - Pm bond frac.', 'O - Pr bond frac.', 'O - Pt bond frac.', 'O - Pu bond frac.', 'O - Rb bond frac.', 'O - Re bond frac.', 'O - Rh bond frac.', 'O - Ru bond frac.', 'O - S bond frac.', 'O - Sb bond frac.', 'O - Sc bond frac.', 'O - Se bond frac.', 'O - Si bond frac.', 'O - Sm bond frac.', 'O - Sn bond frac.', 'O - Sr bond frac.', 'O - Ta bond frac.', 'O - Tb bond frac.', 'O - Tc bond frac.', 'O - Te bond frac.', 'O - Th bond frac.', 'O - Ti bond frac.', 'O - Tl bond frac.', 'O - Tm bond frac.', 'O - U bond frac.', 'O - V bond frac.', 'O - W bond frac.', 'O - Xe bond frac.', 'O - Y bond frac.', 'O - Yb bond frac.', 'O - Zn bond frac.', 'O - Zr bond frac.', 'Os - Os bond frac.', 'Os - P bond frac.', 'Os - Pa bond frac.', 'Os - Pb bond frac.', 'Os - Pd bond frac.', 'Os - Pm bond frac.', 'Os - Pr bond frac.', 'Os - Pt bond frac.', 'Os - Pu bond frac.', 'Os - Rb bond frac.', 'Os - Re bond frac.', 'Os - Rh bond frac.', 'Os - Ru bond frac.', 'Os - S bond frac.', 'Os - Sb bond frac.', 'Os - Sc bond frac.', 'Os - Se bond frac.', 'Os - Si bond frac.', 'Os - Sm bond frac.', 'Os - Sn bond frac.', 'Os - Sr bond frac.', 'Os - Ta bond frac.', 'Os - Tb bond frac.', 'Os - Tc bond frac.', 'Os - Te bond frac.', 'Os - Th bond frac.', 'Os - Ti bond frac.', 'Os - Tl bond frac.', 'Os - Tm bond frac.', 'Os - U bond frac.', 'Os - V bond frac.', 'Os - W bond frac.', 'Os - Xe bond frac.', 'Os - Y bond frac.', 'Os - Yb bond frac.', 'Os - Zn bond frac.', 'Os - Zr bond frac.', 'P - P bond frac.', 'P - Pa bond frac.', 'P - Pb bond frac.', 'P - Pd bond frac.', 'P - Pm bond frac.', 'P - Pr bond frac.', 'P - Pt bond frac.', 'P - Pu bond frac.', 'P - Rb bond frac.', 'P - Re bond frac.', 'P - Rh bond frac.', 'P - Ru bond frac.', 'P - S bond frac.', 'P - Sb bond frac.', 'P - Sc bond frac.', 'P - Se bond frac.', 'P - Si bond frac.', 'P - Sm bond frac.', 'P - Sn bond frac.', 'P - Sr bond frac.', 'P - Ta bond frac.', 'P - Tb bond frac.', 'P - Tc bond frac.', 'P - Te bond frac.', 'P - Th bond frac.', 'P - Ti bond frac.', 'P - Tl bond frac.', 'P - Tm bond frac.', 'P - U bond frac.', 'P - V bond frac.', 'P - W bond frac.', 'P - Xe bond frac.', 'P - Y bond frac.', 'P - Yb bond frac.', 'P - Zn bond frac.', 'P - Zr bond frac.', 'Pa - Pa bond frac.', 'Pa - Pb bond frac.', 'Pa - Pd bond frac.', 'Pa - Pm bond frac.', 'Pa - Pr bond frac.', 'Pa - Pt bond frac.', 'Pa - Pu bond frac.', 'Pa - Rb bond frac.', 'Pa - Re bond frac.', 'Pa - Rh bond frac.', 'Pa - Ru bond frac.', 'Pa - S bond frac.', 'Pa - Sb bond frac.', 'Pa - Sc bond frac.', 'Pa - Se bond frac.', 'Pa - Si bond frac.', 'Pa - Sm bond frac.', 'Pa - Sn bond frac.', 'Pa - Sr bond frac.', 'Pa - Ta bond frac.', 'Pa - Tb bond frac.', 'Pa - Tc bond frac.', 'Pa - Te bond frac.', 'Pa - Th bond frac.', 'Pa - Ti bond frac.', 'Pa - Tl bond frac.', 'Pa - Tm bond frac.', 'Pa - U bond frac.', 'Pa - V bond frac.', 'Pa - W bond frac.', 'Pa - Y bond frac.', 'Pa - Yb bond frac.', 'Pa - Zn bond frac.', 'Pa - Zr bond frac.', 'Pb - Pb bond frac.', 'Pb - Pd bond frac.', 'Pb - Pm bond frac.', 'Pb - Pr bond frac.', 'Pb - Pt bond frac.', 'Pb - Pu bond frac.', 'Pb - Rb bond frac.', 'Pb - Re bond frac.', 'Pb - Rh bond frac.', 'Pb - Ru bond frac.', 'Pb - S bond frac.', 'Pb - Sb bond frac.', 'Pb - Sc bond frac.', 'Pb - Se bond frac.', 'Pb - Si bond frac.', 'Pb - Sm bond frac.', 'Pb - Sn bond frac.', 'Pb - Sr bond frac.', 'Pb - Ta bond frac.', 'Pb - Tb bond frac.', 'Pb - Tc bond frac.', 'Pb - Te bond frac.', 'Pb - Th bond frac.', 'Pb - Ti bond frac.', 'Pb - Tl bond frac.', 'Pb - Tm bond frac.', 'Pb - U bond frac.', 'Pb - V bond frac.', 'Pb - W bond frac.', 'Pb - Xe bond frac.', 'Pb - Y bond frac.', 'Pb - Yb bond frac.', 'Pb - Zn bond frac.', 'Pb - Zr bond frac.', 'Pd - Pd bond frac.', 'Pd - Pm bond frac.', 'Pd - Pr bond frac.', 'Pd - Pt bond frac.', 'Pd - Pu bond frac.', 'Pd - Rb bond frac.', 'Pd - Re bond frac.', 'Pd - Rh bond frac.', 'Pd - Ru bond frac.', 'Pd - S bond frac.', 'Pd - Sb bond frac.', 'Pd - Sc bond frac.', 'Pd - Se bond frac.', 'Pd - Si bond frac.', 'Pd - Sm bond frac.', 'Pd - Sn bond frac.', 'Pd - Sr bond frac.', 'Pd - Ta bond frac.', 'Pd - Tb bond frac.', 'Pd - Tc bond frac.', 'Pd - Te bond frac.', 'Pd - Th bond frac.', 'Pd - Ti bond frac.', 'Pd - Tl bond frac.', 'Pd - Tm bond frac.', 'Pd - U bond frac.', 'Pd - V bond frac.', 'Pd - W bond frac.', 'Pd - Xe bond frac.', 'Pd - Y bond frac.', 'Pd - Yb bond frac.', 'Pd - Zn bond frac.', 'Pd - Zr bond frac.', 'Pm - Pm bond frac.', 'Pm - Pr bond frac.', 'Pm - Pt bond frac.', 'Pm - Pu bond frac.', 'Pm - Rb bond frac.', 'Pm - Rh bond frac.', 'Pm - Ru bond frac.', 'Pm - S bond frac.', 'Pm - Sb bond frac.', 'Pm - Sc bond frac.', 'Pm - Se bond frac.', 'Pm - Si bond frac.', 'Pm - Sm bond frac.', 'Pm - Sn bond frac.', 'Pm - Sr bond frac.', 'Pm - Ta bond frac.', 'Pm - Tb bond frac.', 'Pm - Te bond frac.', 'Pm - Th bond frac.', 'Pm - Ti bond frac.', 'Pm - Tl bond frac.', 'Pm - Tm bond frac.', 'Pm - W bond frac.', 'Pm - Y bond frac.', 'Pm - Yb bond frac.', 'Pm - Zn bond frac.', 'Pm - Zr bond frac.', 'Pr - Pr bond frac.', 'Pr - Pt bond frac.', 'Pr - Rb bond frac.', 'Pr - Re bond frac.', 'Pr - Rh bond frac.', 'Pr - Ru bond frac.', 'Pr - S bond frac.', 'Pr - Sb bond frac.', 'Pr - Sc bond frac.', 'Pr - Se bond frac.', 'Pr - Si bond frac.', 'Pr - Sm bond frac.', 'Pr - Sn bond frac.', 'Pr - Sr bond frac.', 'Pr - Ta bond frac.', 'Pr - Tb bond frac.', 'Pr - Te bond frac.', 'Pr - Th bond frac.', 'Pr - Ti bond frac.', 'Pr - Tl bond frac.', 'Pr - Tm bond frac.', 'Pr - U bond frac.', 'Pr - V bond frac.', 'Pr - W bond frac.', 'Pr - Y bond frac.', 'Pr - Yb bond frac.', 'Pr - Zn bond frac.', 'Pr - Zr bond frac.', 'Pt - Pt bond frac.', 'Pt - Pu bond frac.', 'Pt - Rb bond frac.', 'Pt - Re bond frac.', 'Pt - Rh bond frac.', 'Pt - Ru bond frac.', 'Pt - S bond frac.', 'Pt - Sb bond frac.', 'Pt - Sc bond frac.', 'Pt - Se bond frac.', 'Pt - Si bond frac.', 'Pt - Sm bond frac.', 'Pt - Sn bond frac.', 'Pt - Sr bond frac.', 'Pt - Ta bond frac.', 'Pt - Tb bond frac.', 'Pt - Tc bond frac.', 'Pt - Te bond frac.', 'Pt - Th bond frac.', 'Pt - Ti bond frac.', 'Pt - Tl bond frac.', 'Pt - Tm bond frac.', 'Pt - U bond frac.', 'Pt - V bond frac.', 'Pt - W bond frac.', 'Pt - Xe bond frac.', 'Pt - Y bond frac.', 'Pt - Yb bond frac.', 'Pt - Zn bond frac.', 'Pt - Zr bond frac.', 'Pu - Pu bond frac.', 'Pu - Rb bond frac.', 'Pu - Re bond frac.', 'Pu - Rh bond frac.', 'Pu - Ru bond frac.', 'Pu - S bond frac.', 'Pu - Sb bond frac.', 'Pu - Sc bond frac.', 'Pu - Se bond frac.', 'Pu - Si bond frac.', 'Pu - Sm bond frac.', 'Pu - Sn bond frac.', 'Pu - Sr bond frac.', 'Pu - Ta bond frac.', 'Pu - Tb bond frac.', 'Pu - Tc bond frac.', 'Pu - Te bond frac.', 'Pu - Th bond frac.', 'Pu - Ti bond frac.', 'Pu - Tl bond frac.', 'Pu - Tm bond frac.', 'Pu - U bond frac.', 'Pu - V bond frac.', 'Pu - W bond frac.', 'Pu - Y bond frac.', 'Pu - Yb bond frac.', 'Pu - Zn bond frac.', 'Pu - Zr bond frac.', 'Rb - Rb bond frac.', 'Rb - Re bond frac.', 'Rb - Rh bond frac.', 'Rb - Ru bond frac.', 'Rb - S bond frac.', 'Rb - Sb bond frac.', 'Rb - Sc bond frac.', 'Rb - Se bond frac.', 'Rb - Si bond frac.', 'Rb - Sm bond frac.', 'Rb - Sn bond frac.', 'Rb - Sr bond frac.', 'Rb - Ta bond frac.', 'Rb - Tb bond frac.', 'Rb - Tc bond frac.', 'Rb - Te bond frac.', 'Rb - Th bond frac.', 'Rb - Ti bond frac.', 'Rb - Tl bond frac.', 'Rb - Tm bond frac.', 'Rb - U bond frac.', 'Rb - V bond frac.', 'Rb - W bond frac.', 'Rb - Y bond frac.', 'Rb - Yb bond frac.', 'Rb - Zn bond frac.', 'Rb - Zr bond frac.', 'Re - Re bond frac.', 'Re - Rh bond frac.', 'Re - Ru bond frac.', 'Re - S bond frac.', 'Re - Sb bond frac.', 'Re - Sc bond frac.', 'Re - Se bond frac.', 'Re - Si bond frac.', 'Re - Sm bond frac.', 'Re - Sn bond frac.', 'Re - Sr bond frac.', 'Re - Ta bond frac.', 'Re - Tb bond frac.', 'Re - Tc bond frac.', 'Re - Te bond frac.', 'Re - Th bond frac.', 'Re - Ti bond frac.', 'Re - Tl bond frac.', 'Re - Tm bond frac.', 'Re - U bond frac.', 'Re - V bond frac.', 'Re - W bond frac.', 'Re - Xe bond frac.', 'Re - Y bond frac.', 'Re - Yb bond frac.', 'Re - Zn bond frac.', 'Re - Zr bond frac.', 'Rh - Rh bond frac.', 'Rh - Ru bond frac.', 'Rh - S bond frac.', 'Rh - Sb bond frac.', 'Rh - Sc bond frac.', 'Rh - Se bond frac.', 'Rh - Si bond frac.', 'Rh - Sm bond frac.', 'Rh - Sn bond frac.', 'Rh - Sr bond frac.', 'Rh - Ta bond frac.', 'Rh - Tb bond frac.', 'Rh - Tc bond frac.', 'Rh - Te bond frac.', 'Rh - Th bond frac.', 'Rh - Ti bond frac.', 'Rh - Tl bond frac.', 'Rh - Tm bond frac.', 'Rh - U bond frac.', 'Rh - V bond frac.', 'Rh - W bond frac.', 'Rh - Y bond frac.', 'Rh - Yb bond frac.', 'Rh - Zn bond frac.', 'Rh - Zr bond frac.', 'Ru - Ru bond frac.', 'Ru - S bond frac.', 'Ru - Sb bond frac.', 'Ru - Sc bond frac.', 'Ru - Se bond frac.', 'Ru - Si bond frac.', 'Ru - Sm bond frac.', 'Ru - Sn bond frac.', 'Ru - Sr bond frac.', 'Ru - Ta bond frac.', 'Ru - Tb bond frac.', 'Ru - Tc bond frac.', 'Ru - Te bond frac.', 'Ru - Th bond frac.', 'Ru - Ti bond frac.', 'Ru - Tl bond frac.', 'Ru - Tm bond frac.', 'Ru - U bond frac.', 'Ru - V bond frac.', 'Ru - W bond frac.', 'Ru - Xe bond frac.', 'Ru - Y bond frac.', 'Ru - Yb bond frac.', 'Ru - Zn bond frac.', 'Ru - Zr bond frac.', 'S - S bond frac.', 'S - Sb bond frac.', 'S - Sc bond frac.', 'S - Se bond frac.', 'S - Si bond frac.', 'S - Sm bond frac.', 'S - Sn bond frac.', 'S - Sr bond frac.', 'S - Ta bond frac.', 'S - Tb bond frac.', 'S - Tc bond frac.', 'S - Te bond frac.', 'S - Th bond frac.', 'S - Ti bond frac.', 'S - Tl bond frac.', 'S - Tm bond frac.', 'S - U bond frac.', 'S - V bond frac.', 'S - W bond frac.', 'S - Xe bond frac.', 'S - Y bond frac.', 'S - Yb bond frac.', 'S - Zn bond frac.', 'S - Zr bond frac.', 'Sb - Sb bond frac.', 'Sb - Sc bond frac.', 'Sb - Se bond frac.', 'Sb - Si bond frac.', 'Sb - Sm bond frac.', 'Sb - Sn bond frac.', 'Sb - Sr bond frac.', 'Sb - Ta bond frac.', 'Sb - Tb bond frac.', 'Sb - Tc bond frac.', 'Sb - Te bond frac.', 'Sb - Th bond frac.', 'Sb - Ti bond frac.', 'Sb - Tl bond frac.', 'Sb - Tm bond frac.', 'Sb - U bond frac.', 'Sb - V bond frac.', 'Sb - W bond frac.', 'Sb - Xe bond frac.', 'Sb - Y bond frac.', 'Sb - Yb bond frac.', 'Sb - Zn bond frac.', 'Sb - Zr bond frac.', 'Sc - Sc bond frac.', 'Sc - Se bond frac.', 'Sc - Si bond frac.', 'Sc - Sm bond frac.', 'Sc - Sn bond frac.', 'Sc - Sr bond frac.', 'Sc - Ta bond frac.', 'Sc - Tb bond frac.', 'Sc - Tc bond frac.', 'Sc - Te bond frac.', 'Sc - Th bond frac.', 'Sc - Ti bond frac.', 'Sc - Tl bond frac.', 'Sc - Tm bond frac.', 'Sc - U bond frac.', 'Sc - V bond frac.', 'Sc - W bond frac.', 'Sc - Y bond frac.', 'Sc - Yb bond frac.', 'Sc - Zn bond frac.', 'Sc - Zr bond frac.', 'Se - Se bond frac.', 'Se - Si bond frac.', 'Se - Sm bond frac.', 'Se - Sn bond frac.', 'Se - Sr bond frac.', 'Se - Ta bond frac.', 'Se - Tb bond frac.', 'Se - Tc bond frac.', 'Se - Te bond frac.', 'Se - Th bond frac.', 'Se - Ti bond frac.', 'Se - Tl bond frac.', 'Se - Tm bond frac.', 'Se - U bond frac.', 'Se - V bond frac.', 'Se - W bond frac.', 'Se - Y bond frac.', 'Se - Yb bond frac.', 'Se - Zn bond frac.', 'Se - Zr bond frac.', 'Si - Si bond frac.', 'Si - Sm bond frac.', 'Si - Sn bond frac.', 'Si - Sr bond frac.', 'Si - Ta bond frac.', 'Si - Tb bond frac.', 'Si - Tc bond frac.', 'Si - Te bond frac.', 'Si - Th bond frac.', 'Si - Ti bond frac.', 'Si - Tl bond frac.', 'Si - Tm bond frac.', 'Si - U bond frac.', 'Si - V bond frac.', 'Si - W bond frac.', 'Si - Y bond frac.', 'Si - Yb bond frac.', 'Si - Zn bond frac.', 'Si - Zr bond frac.', 'Sm - Sm bond frac.', 'Sm - Sn bond frac.', 'Sm - Sr bond frac.', 'Sm - Ta bond frac.', 'Sm - Tb bond frac.', 'Sm - Tc bond frac.', 'Sm - Te bond frac.', 'Sm - Th bond frac.', 'Sm - Ti bond frac.', 'Sm - Tl bond frac.', 'Sm - Tm bond frac.', 'Sm - U bond frac.', 'Sm - V bond frac.', 'Sm - W bond frac.', 'Sm - Y bond frac.', 'Sm - Yb bond frac.', 'Sm - Zn bond frac.', 'Sm - Zr bond frac.', 'Sn - Sn bond frac.', 'Sn - Sr bond frac.', 'Sn - Ta bond frac.', 'Sn - Tb bond frac.', 'Sn - Tc bond frac.', 'Sn - Te bond frac.', 'Sn - Th bond frac.', 'Sn - Ti bond frac.', 'Sn - Tl bond frac.', 'Sn - Tm bond frac.', 'Sn - U bond frac.', 'Sn - V bond frac.', 'Sn - W bond frac.', 'Sn - Y bond frac.', 'Sn - Yb bond frac.', 'Sn - Zn bond frac.', 'Sn - Zr bond frac.', 'Sr - Sr bond frac.', 'Sr - Ta bond frac.', 'Sr - Tb bond frac.', 'Sr - Tc bond frac.', 'Sr - Te bond frac.', 'Sr - Th bond frac.', 'Sr - Ti bond frac.', 'Sr - Tl bond frac.', 'Sr - Tm bond frac.', 'Sr - U bond frac.', 'Sr - V bond frac.', 'Sr - W bond frac.', 'Sr - Xe bond frac.', 'Sr - Y bond frac.', 'Sr - Yb bond frac.', 'Sr - Zn bond frac.', 'Sr - Zr bond frac.', 'Ta - Ta bond frac.', 'Ta - Tb bond frac.', 'Ta - Tc bond frac.', 'Ta - Te bond frac.', 'Ta - Th bond frac.', 'Ta - Ti bond frac.', 'Ta - Tl bond frac.', 'Ta - Tm bond frac.', 'Ta - U bond frac.', 'Ta - V bond frac.', 'Ta - W bond frac.', 'Ta - Y bond frac.', 'Ta - Yb bond frac.', 'Ta - Zn bond frac.', 'Ta - Zr bond frac.', 'Tb - Tb bond frac.', 'Tb - Tc bond frac.', 'Tb - Te bond frac.', 'Tb - Th bond frac.', 'Tb - Ti bond frac.', 'Tb - Tl bond frac.', 'Tb - Tm bond frac.', 'Tb - U bond frac.', 'Tb - V bond frac.', 'Tb - W bond frac.', 'Tb - Y bond frac.', 'Tb - Yb bond frac.', 'Tb - Zn bond frac.', 'Tb - Zr bond frac.', 'Tc - Tc bond frac.', 'Tc - Te bond frac.', 'Tc - Th bond frac.', 'Tc - Ti bond frac.', 'Tc - Tl bond frac.', 'Tc - Tm bond frac.', 'Tc - U bond frac.', 'Tc - V bond frac.', 'Tc - W bond frac.', 'Tc - Xe bond frac.', 'Tc - Y bond frac.', 'Tc - Yb bond frac.', 'Tc - Zn bond frac.', 'Tc - Zr bond frac.', 'Te - Te bond frac.', 'Te - Th bond frac.', 'Te - Ti bond frac.', 'Te - Tl bond frac.', 'Te - Tm bond frac.', 'Te - U bond frac.', 'Te - V bond frac.', 'Te - W bond frac.', 'Te - Xe bond frac.', 'Te - Y bond frac.', 'Te - Yb bond frac.', 'Te - Zn bond frac.', 'Te - Zr bond frac.', 'Th - Th bond frac.', 'Th - Ti bond frac.', 'Th - Tl bond frac.', 'Th - Tm bond frac.', 'Th - U bond frac.', 'Th - V bond frac.', 'Th - W bond frac.', 'Th - Y bond frac.', 'Th - Yb bond frac.', 'Th - Zn bond frac.', 'Th - Zr bond frac.', 'Ti - Ti bond frac.', 'Ti - Tl bond frac.', 'Ti - Tm bond frac.', 'Ti - U bond frac.', 'Ti - V bond frac.', 'Ti - W bond frac.', 'Ti - Y bond frac.', 'Ti - Yb bond frac.', 'Ti - Zn bond frac.', 'Ti - Zr bond frac.', 'Tl - Tl bond frac.', 'Tl - Tm bond frac.', 'Tl - U bond frac.', 'Tl - V bond frac.', 'Tl - W bond frac.', 'Tl - Y bond frac.', 'Tl - Yb bond frac.', 'Tl - Zn bond frac.', 'Tl - Zr bond frac.', 'Tm - Tm bond frac.', 'Tm - U bond frac.', 'Tm - V bond frac.', 'Tm - W bond frac.', 'Tm - Y bond frac.', 'Tm - Yb bond frac.', 'Tm - Zn bond frac.', 'Tm - Zr bond frac.', 'U - U bond frac.', 'U - V bond frac.', 'U - W bond frac.', 'U - Y bond frac.', 'U - Yb bond frac.', 'U - Zn bond frac.', 'U - Zr bond frac.', 'V - V bond frac.', 'V - W bond frac.', 'V - Xe bond frac.', 'V - Y bond frac.', 'V - Yb bond frac.', 'V - Zn bond frac.', 'V - Zr bond frac.', 'W - W bond frac.', 'W - Xe bond frac.', 'W - Y bond frac.', 'W - Yb bond frac.', 'W - Zn bond frac.', 'W - Zr bond frac.', 'Xe - Xe bond frac.', 'Xe - Zn bond frac.', 'Y - Y bond frac.', 'Y - Yb bond frac.', 'Y - Zn bond frac.', 'Y - Zr bond frac.', 'Yb - Yb bond frac.', 'Yb - Zn bond frac.', 'Yb - Zr bond frac.', 'Zn - Zn bond frac.', 'Zn - Zr bond frac.', 'Zr - Zr bond frac.'])
    # Drop columns: 'volume', 'density_y' and 3 other columns
    merged_df = merged_df.drop(columns=['volume', 'density_y', 'band_gap_y', 'formation_energy_per_atom_y', 'energy_above_hull_y'])
    # Drop columns: 'formula_pretty', 'packing fraction'
    merged_df = merged_df.drop(columns=['formula_pretty', 'packing fraction'])
    # Drop columns: 'mean Voro_index_3', 'std_dev Voro_index_3' and 12 other columns
    merged_df = merged_df.drop(columns=['mean Voro_index_3', 'std_dev Voro_index_3', 'mean Voro_index_4', 'std_dev Voro_index_4', 'mean Voro_index_5', 'std_dev Voro_index_5', 'mean Voro_index_6', 'std_dev Voro_index_6', 'mean Voro_index_7', 'std_dev Voro_index_7', 'mean Voro_index_8', 'std_dev Voro_index_8', 'mean Voro_index_9', 'std_dev Voro_index_9'])
    # Drop column: 'max packing efficiency'
    merged_df = merged_df.drop(columns=['max packing efficiency'])
    # Drop columns: 'std_dev Voro_index_10', 'mean Symmetry_index_3' and 15 other columns
    merged_df = merged_df.drop(columns=['std_dev Voro_index_10', 'mean Symmetry_index_3', 'std_dev Symmetry_index_3', 'mean Symmetry_index_4', 'std_dev Symmetry_index_4', 'mean Symmetry_index_5', 'std_dev Symmetry_index_5', 'mean Symmetry_index_6', 'std_dev Symmetry_index_6', 'mean Symmetry_index_7', 'std_dev Symmetry_index_7', 'mean Symmetry_index_8', 'std_dev Symmetry_index_8', 'mean Symmetry_index_9', 'std_dev Symmetry_index_9', 'mean Symmetry_index_10', 'std_dev Symmetry_index_10'])
    # Drop columns: 'mean Voro_vol_sum', 'std_dev Voro_vol_sum' and 2 other columns
    merged_df = merged_df.drop(columns=['mean Voro_vol_sum', 'std_dev Voro_vol_sum', 'mean Voro_area_sum', 'std_dev Voro_area_sum'])
    # Drop column: 'mean Voro_vol_std_dev'
    merged_df = merged_df.drop(columns=['mean Voro_vol_std_dev'])
    # Drop column: 'std_dev Voro_vol_mean'
    merged_df = merged_df.drop(columns=['std_dev Voro_vol_mean'])
    # Drop column: 'std_dev Voro_vol_std_dev'
    merged_df = merged_df.drop(columns=['std_dev Voro_vol_std_dev'])
    # Drop columns: 'mean Voro_vol_minimum', 'std_dev Voro_vol_minimum' and 3 other columns
    merged_df = merged_df.drop(columns=['mean Voro_vol_minimum', 'std_dev Voro_vol_minimum', 'mean Voro_vol_maximum', 'std_dev Voro_vol_maximum', 'mean Voro_area_mean'])
    # Drop columns: 'std_dev Voro_area_minimum', 'std_dev Voro_area_mean' and 2 other columns
    merged_df = merged_df.drop(columns=['std_dev Voro_area_minimum', 'std_dev Voro_area_mean', 'mean Voro_area_std_dev', 'mean Voro_area_minimum'])
    # Drop column: 'mean Voro_area_maximum'
    merged_df = merged_df.drop(columns=['mean Voro_area_maximum'])
    # Drop column: 'std_dev Voro_area_maximum'
    merged_df = merged_df.drop(columns=['std_dev Voro_area_maximum'])
    # Drop columns: 'mean Voro_dist_mean', 'mean Voro_dist_std_dev' and 3 other columns
    merged_df = merged_df.drop(columns=['mean Voro_dist_mean', 'mean Voro_dist_std_dev', 'std_dev Voro_dist_std_dev', 'mean Voro_dist_minimum', 'std_dev Voro_dist_minimum'])
    return merged_df

merged_df_clean = clean_data(merged_df.copy())
merged_df_clean.head()
# Out:
#   material_id  band_gap_x  formation_energy_per_atom_x  \
# 0  mp-1244933      0.0000                     0.349291
# 1  mp-1244953      0.0000                     0.095724
# 2  mp-1244990      0.0000                     0.366274
# 3  mp-1180008      1.2773                     0.419854
# 4  mp-1180064      0.0423                     0.387014
#
#    MagpieData minimum Number  MagpieData maximum Number  \
# 0                       14.0                       14.0
# 1                       13.0                       13.0
# 2                       14.0                       14.0
# 3                        8.0                        8.0
# 4                        8.0                        8.0
#
#    MagpieData range Number  MagpieData mean Number  MagpieData avg_dev Number  \
# 0                      0.0                    14.0                        0.0
# 1                      0.0                    13.0                        0.0
# ...

# %%
"""
Cell generated by Data Wrangler.
"""
def clean_data(merged_df_clean):
    # Drop columns: 'n_paths', 'em_std' and 4 other columns
    merged_df_clean = merged_df_clean.drop(columns=['n_paths', 'em_std', 'em_min', '_split', 'chemsys', 'crystal_system'])
    return merged_df_clean

merged_df_clean_1 = clean_data(merged_df_clean.copy())
merged_df_clean_1.head()
# Out:
#   material_id  band_gap_x  formation_energy_per_atom_x  \
# 0  mp-1244933      0.0000                     0.349291
# 1  mp-1244953      0.0000                     0.095724
# 2  mp-1244990      0.0000                     0.366274
# 3  mp-1180008      1.2773                     0.419854
# 4  mp-1180064      0.0423                     0.387014
#
#    MagpieData minimum Number  MagpieData maximum Number  \
# 0                       14.0                       14.0
# 1                       13.0                       13.0
# 2                       14.0                       14.0
# 3                        8.0                        8.0
# 4                        8.0                        8.0
#
#    MagpieData range Number  MagpieData mean Number  MagpieData avg_dev Number  \
# 0                      0.0                    14.0                        0.0
# 1                      0.0                    13.0                        0.0
# ...

# %%
from pymatgen.symmetry.groups import SpaceGroup

# Step 1: Process only unique space group symbols
unique_symbols = merged_df_clean_1['space_group'].unique()

# Step 2: Build mapping (symbol ➔ number)
symbol_to_number = {}
for symbol in unique_symbols:
    try:
        sg = SpaceGroup(symbol)
        symbol_to_number[symbol] = sg.int_number
    except:
        symbol_to_number[symbol] = None  # Handle bad symbols if needed

# Step 3: Map numbers back to full dataset
merged_df_clean_1['space_group_number'] = merged_df_clean_1['space_group'].map(symbol_to_number)

# %%
merged_df_clean_1.drop(columns=['space_group'], inplace=True)

# %%
targets = ['band_gap_x',
           'formation_energy_per_atom_x',
           'mean Voro_index_10',
           'mean Voro_vol_mean',
           'std_dev Voro_area_std_dev',
           'std_dev Voro_dist_mean',
           'mean Voro_dist_maximum',
           'std_dev Voro_dist_maximum',
           'density_x',
           'vpa',
           'E_1D',
           'E_2D',
           'E_3D',
           'em_mean',
           ]

# Splitting to input and outputs
input = merged_df_clean_1.drop(targets, axis =1)
output = merged_df_clean_1[targets]

input.to_csv('/Users/navin/Library/CloudStorage/Dropbox-AIZOTH/研究/Navin/NIMS/surrogate-DFT-ionic-conductivity/src/20250715_multitask_customXG/data/input_model1.csv', index = False)
output.to_csv('/Users/navin/Library/CloudStorage/Dropbox-AIZOTH/研究/Navin/NIMS/surrogate-DFT-ionic-conductivity/src/20250715_multitask_customXG/data/output_model1.csv', index = False)
